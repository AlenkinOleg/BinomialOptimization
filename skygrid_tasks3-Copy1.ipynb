# %%
import numpy as np
import pandas as pd
import re
import json

# %% [markdown]
# # Import skygrid client

# %%
import time

from disneylandClient import (
    new_client,
    Job,
    RequestWithId,
)

STATUS_IN_PROCESS = set([
    Job.PENDING,
    Job.PULLED,
    Job.RUNNING,
])
STATUS_FINAL = set([
    Job.COMPLETED,
    Job.FAILED,
])

def return_descriptor(f_name, n_iteration=50, n_attempts=20, dims=2, low_f=25, high_f=50, bound=1):
    
    initial_size = 2 * dims + 3
    
    cmd = "python /opt/script.py --f_name "+f_name+" --n_iteration="+str(n_iteration)+" --n_attempts="+str(n_attempts)+\
          " --low_f="+str(low_f)+" --high_f="+str(high_f)+" --dims="+str(dims)+" --initial_size="+str(initial_size)+\
          " --bound="+str(bound)

    descriptor = {
        "input": [],

        "container": {
            "workdir": "",
            "name": "oleg94/kek",
            "cpu_needed": 4,
            "max_memoryMB": 4096,
            "min_memoryMB": 2048,
            "cmd": cmd,
        },

        "required_outputs": {
            "output_uri": "none:",
            "file_contents": [
                {"file": "output.txt", "to_variable": "out"}
            ]
        }
    }
    
    return descriptor

# %% [markdown]
# # Send tasks

# %%
stub = new_client()
jobs = {}

# %%
for bound in [1]:
    for f_name in ['beale', 'eg1', 'engval2']:#, 'pspdoc', 'scalable', 'gsobol', 'biggs5', 'sqmichalewicz5']:
        for dims in [2]:
            for k in range(5):
                for low_f, high_f in [(20, 40), (50, 100)]:
                    descriptor = return_descriptor(f_name, bound=bound, dims=dims, low_f=low_f, high_f=high_f)
                    key = f_name+"_"+str(bound)+"_"+str(dims)+"_"+str(low_f)+"_"+str(high_f)+"_ind"+str(k)
                    jobs[key] = Job(input=json.dumps(descriptor), kind="docker")
                    jobs[key] = stub.CreateJob(jobs[key])

# %% [markdown]
# # Get results

# %%
for k in jobs.keys():
    jobs[k] = stub.GetJob(RequestWithId(id=jobs[k].id))

for k in jobs.keys():
    if jobs[k].status == Job.COMPLETED:
        print(k, ": finished")
    elif jobs[k].status == Job.PENDING:
        print(k, ": pending")
    elif jobs[k].status == Job.PULLED:
        print(k, ": pulled")
    elif jobs[k].status == Job.RUNNING:
        print(k, ": running")
    else:
        print(k, ": failed")
# Out:
# beale_1_2_20_40_ind0 : failed
# beale_1_2_50_100_ind0 : failed
# beale_1_2_20_40_ind1 : failed
# beale_1_2_50_100_ind1 : failed
# beale_1_2_20_40_ind2 : failed
# beale_1_2_50_100_ind2 : failed
# beale_1_2_20_40_ind3 : failed
# beale_1_2_50_100_ind3 : failed
# beale_1_2_20_40_ind4 : failed
# beale_1_2_50_100_ind4 : failed
# beale_1_2_20_40_ind5 : failed
# beale_1_2_50_100_ind5 : failed
# beale_1_2_20_40_ind6 : failed
# beale_1_2_50_100_ind6 : failed
# beale_1_2_20_40_ind7 : failed
# beale_1_2_50_100_ind7 : failed
# beale_1_2_20_40_ind8 : failed
# beale_1_2_50_100_ind8 : failed
# beale_1_2_20_40_ind9 : failed
# beale_1_2_50_100_ind9 : failed
# eg1_1_2_20_40_ind0 : finished
# eg1_1_2_50_100_ind0 : running
# eg1_1_2_20_40_ind1 : finished
# eg1_1_2_50_100_ind1 : running
# eg1_1_2_20_40_ind2 : finished
# eg1_1_2_50_100_ind2 : finished
# eg1_1_2_20_40_ind3 : running
# eg1_1_2_50_100_ind3 : finished
# eg1_1_2_20_40_ind4 : running
# eg1_1_2_50_100_ind4 : finished
# eg1_1_2_20_40_ind5 : failed
# eg1_1_2_50_100_ind5 : failed
# eg1_1_2_20_40_ind6 : failed
# eg1_1_2_50_100_ind6 : failed
# eg1_1_2_20_40_ind7 : failed
# eg1_1_2_50_100_ind7 : failed
# eg1_1_2_20_40_ind8 : failed
# eg1_1_2_50_100_ind8 : failed
# eg1_1_2_20_40_ind9 : failed
# eg1_1_2_50_100_ind9 : failed
# engval2_1_2_20_40_ind0 : finished
# engval2_1_2_50_100_ind0 : finished
# engval2_1_2_20_40_ind1 : finished
# engval2_1_2_50_100_ind1 : finished
# engval2_1_2_20_40_ind2 : finished
# engval2_1_2_50_100_ind2 : finished
# engval2_1_2_20_40_ind3 : finished
# engval2_1_2_50_100_ind3 : finished
# engval2_1_2_20_40_ind4 : running
# engval2_1_2_50_100_ind4 : finished
# engval2_1_2_20_40_ind5 : failed
# engval2_1_2_50_100_ind5 : failed
# engval2_1_2_20_40_ind6 : failed
# engval2_1_2_50_100_ind6 : failed
# engval2_1_2_20_40_ind7 : failed
# engval2_1_2_50_100_ind7 : failed
# engval2_1_2_20_40_ind8 : failed
# engval2_1_2_50_100_ind8 : failed
# engval2_1_2_20_40_ind9 : failed
# engval2_1_2_50_100_ind9 : failed
# pspdoc_1_2_20_40_ind0 : failed
# pspdoc_1_2_50_100_ind0 : failed
# pspdoc_1_2_20_40_ind1 : failed
# pspdoc_1_2_50_100_ind1 : failed
# pspdoc_1_2_20_40_ind2 : failed
# pspdoc_1_2_50_100_ind2 : failed
# pspdoc_1_2_20_40_ind3 : failed
# pspdoc_1_2_50_100_ind3 : failed
# pspdoc_1_2_20_40_ind4 : failed
# pspdoc_1_2_50_100_ind4 : failed
# pspdoc_1_2_20_40_ind5 : failed
# pspdoc_1_2_50_100_ind5 : failed
# pspdoc_1_2_20_40_ind6 : failed
# pspdoc_1_2_50_100_ind6 : failed
# pspdoc_1_2_20_40_ind7 : failed
# pspdoc_1_2_50_100_ind7 : failed
# pspdoc_1_2_20_40_ind8 : failed
# pspdoc_1_2_50_100_ind8 : failed
# pspdoc_1_2_20_40_ind9 : failed
# pspdoc_1_2_50_100_ind9 : failed
# rosenbrock_1_2_20_40_ind0 : failed
# rosenbrock_1_2_50_100_ind0 : failed
# rosenbrock_1_2_20_40_ind1 : failed
# rosenbrock_1_2_50_100_ind1 : finished
# rosenbrock_1_2_20_40_ind2 : failed
# rosenbrock_1_2_50_100_ind2 : finished
# rosenbrock_1_2_20_40_ind3 : finished
# rosenbrock_1_2_50_100_ind3 : finished
# rosenbrock_1_2_20_40_ind4 : failed
# rosenbrock_1_2_50_100_ind4 : failed
# rosenbrock_1_2_20_40_ind5 : failed
# rosenbrock_1_2_50_100_ind5 : failed
# rosenbrock_1_2_20_40_ind6 : failed
# rosenbrock_1_2_50_100_ind6 : failed
# rosenbrock_1_2_20_40_ind7 : failed
# rosenbrock_1_2_50_100_ind7 : failed
# rosenbrock_1_2_20_40_ind8 : failed
# rosenbrock_1_2_50_100_ind8 : failed
# rosenbrock_1_2_20_40_ind9 : failed
# rosenbrock_1_2_50_100_ind9 : failed
# scalable_1_2_20_40_ind0 : failed
# scalable_1_2_50_100_ind0 : failed
# scalable_1_2_20_40_ind1 : failed
# scalable_1_2_50_100_ind1 : failed
# scalable_1_2_20_40_ind2 : failed
# scalable_1_2_50_100_ind2 : failed
# scalable_1_2_20_40_ind3 : failed
# scalable_1_2_50_100_ind3 : failed
# scalable_1_2_20_40_ind4 : failed
# scalable_1_2_50_100_ind4 : failed
# scalable_1_2_20_40_ind5 : failed
# scalable_1_2_50_100_ind5 : failed
# scalable_1_2_20_40_ind6 : failed
# scalable_1_2_50_100_ind6 : failed
# scalable_1_2_20_40_ind7 : failed
# scalable_1_2_50_100_ind7 : failed
# scalable_1_2_20_40_ind8 : failed
# scalable_1_2_50_100_ind8 : failed
# scalable_1_2_20_40_ind9 : failed
# scalable_1_2_50_100_ind9 : failed
# michalewicz_1_2_20_40_ind0 : failed
# michalewicz_1_2_50_100_ind0 : failed
# michalewicz_1_2_20_40_ind1 : failed
# michalewicz_1_2_50_100_ind1 : failed
# michalewicz_1_2_20_40_ind2 : failed
# michalewicz_1_2_50_100_ind2 : failed
# michalewicz_1_2_20_40_ind3 : failed
# michalewicz_1_2_50_100_ind3 : failed
# michalewicz_1_2_20_40_ind4 : failed
# michalewicz_1_2_50_100_ind4 : failed
# michalewicz_1_2_20_40_ind5 : failed
# michalewicz_1_2_50_100_ind5 : failed
# michalewicz_1_2_20_40_ind6 : failed
# michalewicz_1_2_50_100_ind6 : failed
# michalewicz_1_2_20_40_ind7 : failed
# michalewicz_1_2_50_100_ind7 : failed
# michalewicz_1_2_20_40_ind8 : failed
# michalewicz_1_2_50_100_ind8 : failed
# michalewicz_1_2_20_40_ind9 : failed
# michalewicz_1_2_50_100_ind9 : failed
# ackley1_1_2_20_40_ind0 : failed
# ackley1_1_2_50_100_ind0 : failed
# ackley1_1_2_20_40_ind1 : failed
# ackley1_1_2_50_100_ind1 : failed
# ackley1_1_2_20_40_ind2 : failed
# ackley1_1_2_50_100_ind2 : failed
# ackley1_1_2_20_40_ind3 : failed
# ackley1_1_2_50_100_ind3 : failed
# ackley1_1_2_20_40_ind4 : failed
# ackley1_1_2_50_100_ind4 : failed
# ackley1_1_2_20_40_ind5 : failed
# ackley1_1_2_50_100_ind5 : failed
# ackley1_1_2_20_40_ind6 : failed
# ackley1_1_2_50_100_ind6 : failed
# ackley1_1_2_20_40_ind7 : failed
# ackley1_1_2_50_100_ind7 : failed
# ackley1_1_2_20_40_ind8 : failed
# ackley1_1_2_50_100_ind8 : failed
# ackley1_1_2_20_40_ind9 : failed
# ackley1_1_2_50_100_ind9 : failed
# gsobol_1_2_20_40_ind0 : failed
# gsobol_1_2_50_100_ind0 : failed
# gsobol_1_2_20_40_ind1 : failed
# gsobol_1_2_50_100_ind1 : failed
# gsobol_1_2_20_40_ind2 : failed
# gsobol_1_2_50_100_ind2 : failed
# gsobol_1_2_20_40_ind3 : failed
# gsobol_1_2_50_100_ind3 : failed
# gsobol_1_2_20_40_ind4 : failed
# gsobol_1_2_50_100_ind4 : failed
# gsobol_1_2_20_40_ind5 : failed
# gsobol_1_2_50_100_ind5 : failed
# gsobol_1_2_20_40_ind6 : failed
# gsobol_1_2_50_100_ind6 : failed
# gsobol_1_2_20_40_ind7 : failed
# gsobol_1_2_50_100_ind7 : failed
# gsobol_1_2_20_40_ind8 : failed
# gsobol_1_2_50_100_ind8 : failed
# gsobol_1_2_20_40_ind9 : failed
# gsobol_1_2_50_100_ind9 : failed
# biggs5_1_2_20_40_ind0 : failed
# biggs5_1_2_50_100_ind0 : failed
# biggs5_1_2_20_40_ind1 : failed
# biggs5_1_2_50_100_ind1 : failed
# biggs5_1_2_20_40_ind2 : failed
# biggs5_1_2_50_100_ind2 : failed
# biggs5_1_2_20_40_ind3 : failed
# biggs5_1_2_50_100_ind3 : failed
# biggs5_1_2_20_40_ind4 : failed
# biggs5_1_2_50_100_ind4 : failed
# biggs5_1_2_20_40_ind5 : failed
# biggs5_1_2_50_100_ind5 : failed
# biggs5_1_2_20_40_ind6 : failed
# biggs5_1_2_50_100_ind6 : failed
# biggs5_1_2_20_40_ind7 : failed
# biggs5_1_2_50_100_ind7 : failed
# biggs5_1_2_20_40_ind8 : failed
# biggs5_1_2_50_100_ind8 : failed
# biggs5_1_2_20_40_ind9 : failed
# biggs5_1_2_50_100_ind9 : failed
# michalewicz5_1_2_20_40_ind0 : failed
# michalewicz5_1_2_50_100_ind0 : failed
# michalewicz5_1_2_20_40_ind1 : failed
# michalewicz5_1_2_50_100_ind1 : failed
# michalewicz5_1_2_20_40_ind2 : failed
# michalewicz5_1_2_50_100_ind2 : failed
# michalewicz5_1_2_20_40_ind3 : failed
# michalewicz5_1_2_50_100_ind3 : failed
# michalewicz5_1_2_20_40_ind4 : failed
# michalewicz5_1_2_50_100_ind4 : failed
# michalewicz5_1_2_20_40_ind5 : failed
# michalewicz5_1_2_50_100_ind5 : failed
# michalewicz5_1_2_20_40_ind6 : failed
# michalewicz5_1_2_50_100_ind6 : failed
# michalewicz5_1_2_20_40_ind7 : failed
# michalewicz5_1_2_50_100_ind7 : failed
# michalewicz5_1_2_20_40_ind8 : failed
# michalewicz5_1_2_50_100_ind8 : failed
# michalewicz5_1_2_20_40_ind9 : failed
# michalewicz5_1_2_50_100_ind9 : failed
# sqmichalewicz5_1_2_20_40_ind0 : failed
# sqmichalewicz5_1_2_50_100_ind0 : failed
# sqmichalewicz5_1_2_20_40_ind1 : failed
# sqmichalewicz5_1_2_50_100_ind1 : failed
# sqmichalewicz5_1_2_20_40_ind2 : failed
# sqmichalewicz5_1_2_50_100_ind2 : failed
# sqmichalewicz5_1_2_20_40_ind3 : failed
# sqmichalewicz5_1_2_50_100_ind3 : failed
# sqmichalewicz5_1_2_20_40_ind4 : failed
# sqmichalewicz5_1_2_50_100_ind4 : failed
# sqmichalewicz5_1_2_20_40_ind5 : failed
# sqmichalewicz5_1_2_50_100_ind5 : finished
# sqmichalewicz5_1_2_20_40_ind6 : failed
# sqmichalewicz5_1_2_50_100_ind6 : failed
# sqmichalewicz5_1_2_20_40_ind7 : failed
# sqmichalewicz5_1_2_50_100_ind7 : failed
# sqmichalewicz5_1_2_20_40_ind8 : finished
# sqmichalewicz5_1_2_50_100_ind8 : failed
# sqmichalewicz5_1_2_20_40_ind9 : failed
# sqmichalewicz5_1_2_50_100_ind9 : failed

# %%
for key in jobs.keys():
    if key:
        if jobs[key].status == Job.COMPLETED:
            output = json.loads(re.sub(r"\\", '', jobs[key].output[15:-2]))
            with open('50repeats/'+key+'.txt', 'w') as f:
                json.dump(output, f)

# %%
output = json.loads(re.sub(r"\\", '', jobs['eg1_1_2_50_100_ind4'].output[15:-2]))

# %%
# with open('skygrid_results_new/ackley1_1_2_100_200.txt', 'rb') as f:
#     output = json.load(f)

# %%
agg = np.array(output)
for i in range(len(agg)):
    for j in range(len(agg[i])):
        for k in range(len(agg[i,j])):
            agg[i,j,k] = np.array(agg[i,j,k])

# %%
def return_track(agg, objective, type_track='true'):
    
    tracks = []
    
    if type_track=='true':
        
        for i in range(len(agg)):
            subtracks = []
            for j in range(len(agg[i])):
                argmins = agg[i, j, 1][agg[i, j, 4]]
                values = objective(argmins)
                subtracks.append(values)
            tracks.append(subtracks)
        return np.array(tracks).mean(axis=1), np.array(tracks).std(axis=1)
        
            
    
    elif type_track=='noisy':
        
        for i in range(len(agg)):
            subtracks = []
            for j in range(len(agg[i])):
                subtracks.append(np.minimum.accumulate(agg[i, j, 2] / agg[i, j, 3]))
            tracks.append(subtracks)
        return np.array(tracks).mean(axis=1), np.array(tracks).std(axis=1)

# %%
import numpy as np
import GPy
import GPyOpt
import math
from scipy.optimize import minimize, differential_evolution
from scipy.stats import norm, beta
import matplotlib.pyplot as plt
import pickle

# %matplotlib inline

from functionDoESpecial import functionDoESpecial, function_dimensions, function_names
from binomial_optimization2 import optimization_step, value_generator

bound = 1
dims = 2

objective = lambda x: functionDoESpecial(x.reshape(1, -1), 'ackley1')
if f_name in function_dimensions.keys():
    dims = function_dimensions[f_name]

lower_bounds = [-1 * bound] * dims
upper_bounds = [bound] * dims

space = []
for i in range(len(lower_bounds)):
    space.append({'name': 'x'+str(i), 'type': 'continuous', 'domain': (lower_bounds[i], upper_bounds[i])})

feasible_region = GPyOpt.Design_space(space=space)

#search max and min
argmin = differential_evolution(objective, [(-bound, bound)] * dims).x
argmax = differential_evolution(lambda x: -1 * objective(x), [(-bound, bound)] * dims).x
max_v = objective(argmax)
min_v = objective(argmin)
#normalize function
ackley1 = lambda x: (functionDoESpecial(x, 'ackley1') * 0.95 - min_v) / (max_v - min_v)

# %%
bound = 1
dims = 2

f_name = 'engval2'
objective = lambda x: functionDoESpecial(x.reshape(1, -1), f_name)
if f_name in function_dimensions.keys():
    dims = function_dimensions[f_name]

lower_bounds = [0] * dims
upper_bounds = [1] * dims

space = []
for i in range(len(lower_bounds)):
    space.append({'name': 'x'+str(i), 'type': 'continuous', 'domain': (lower_bounds[i], upper_bounds[i])})

feasible_region = GPyOpt.Design_space(space=space)

#search max and min
argmin = differential_evolution(objective, [(0, 1)] * dims).x
argmax = differential_evolution(lambda x: -1 * objective(x), [(0, 1)] * dims).x
max_v = objective(argmax)
min_v = objective(argmin)
#normalize function
engval2 = lambda x: (functionDoESpecial(x, f_name) * 0.95 - min_v) / (max_v - min_v)

# %%
bound = 1
dims = 2

objective = lambda x: functionDoESpecial(x.reshape(1, -1), 'sqmichalewicz5')
if f_name in function_dimensions.keys():
    dims = function_dimensions[f_name]

lower_bounds = [0] * dims
upper_bounds = [bound] * dims

space = []
for i in range(len(lower_bounds)):
    space.append({'name': 'x'+str(i), 'type': 'continuous', 'domain': (lower_bounds[i], upper_bounds[i])})

feasible_region = GPyOpt.Design_space(space=space)

#search max and min
argmin = differential_evolution(objective, [(0, 1)] * dims).x
argmax = differential_evolution(lambda x: -1 * objective(x), [(-bound, bound)] * dims).x
max_v = objective(argmax)
min_v = objective(argmin)
#normalize function
sqmichalewicz5 = lambda x: (functionDoESpecial(x, 'sqmichalewicz5') * 0.95 - min_v) / (max_v - min_v)

# %%
bound = 100
dims = 2

objective = lambda x: functionDoESpecial(x.reshape(1, -1), 'rosenbrock')
if f_name in function_dimensions.keys():
    dims = function_dimensions[f_name]

lower_bounds = [-1 * bound] * dims
upper_bounds = [bound] * dims

space = []
for i in range(len(lower_bounds)):
    space.append({'name': 'x'+str(i), 'type': 'continuous', 'domain': (lower_bounds[i], upper_bounds[i])})

feasible_region = GPyOpt.Design_space(space=space)

#search max and min
argmin = differential_evolution(objective, [(-bound, bound)] * dims).x
argmax = differential_evolution(lambda x: -1 * objective(x), [(-bound, bound)] * dims).x
max_v = objective(argmax)
min_v = objective(argmin)
#normalize function
rosenbrock = lambda x: (functionDoESpecial(x, 'rosenbrock') * 0.95 - min_v) / (max_v - min_v)

# %%
means, stds = return_track(agg, eg1)

cut=10
plt.figure(figsize=(15, 5))
plt.errorbar(np.arange(len(means[0][cut:])),  means[0][cut:], yerr=stds[0][cut:], label='gp 25')
plt.errorbar(np.arange(len(means[1][cut:])),  means[1][cut:], yerr=stds[1][cut:], label='gp 50')
plt.errorbar(np.arange(len(means[2][cut:])),  means[2][cut:], yerr=stds[2][cut:], label='ggpm 50')
plt.errorbar(np.arange(len(means[3][cut:])),  means[3][cut:], yerr=stds[3][cut:], label='ggpm 25')
plt.errorbar(np.arange(len(means[4][cut:])),  means[4][cut:], yerr=stds[4][cut:], label='ggpm 0.5')
plt.errorbar(np.arange(len(means[5][cut:])),  means[5][cut:], yerr=stds[5][cut:], label='ggpm dfid')
# plt.yscale('log', nonposy='clip')
plt.ylabel('Best point true value')
plt.xlabel('iteration')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-7f5fa34245c3> in <module>()
# ----> 1 means, stds = return_track(agg, eg1)
#       2
#       3 cut=10
#       4 plt.figure(figsize=(15, 5))
#       5 plt.errorbar(np.arange(len(means[0][cut:])),  means[0][cut:], yerr=stds[0][cut:], label='gp 25')
#
# NameError: name 'eg1' is not defined

# %%
means, stds = return_track(agg, ackley1)

plt.figure(figsize=(15, 5))
plt.suptitle("Ackley1 2D", fontsize=20)
plt.subplot(1,2,1)
# plt.title("Best point value per iteration", fontsize=18)
plt.plot(np.arange(len(means[0])),  means[0], label='Gaussian, f=100')
plt.fill_between(np.arange(len(means[0])), means[0]+stds[0], means[0]-stds[0], alpha=0.1)
plt.plot(np.arange(len(means[1])),  means[1], label='Gaussian, f=200')
plt.fill_between(np.arange(len(means[1])), means[1]+stds[1], means[1]-stds[1], alpha=0.1)
plt.plot(np.arange(len(means[2])),  means[2], label='Binomial, f=200')
plt.fill_between(np.arange(len(means[2])), means[2]+stds[2], means[2]-stds[2], alpha=0.1)
plt.plot(np.arange(len(means[3])),  means[3], label='Binomial, f=100')
plt.fill_between(np.arange(len(means[3])), means[3]+stds[3], means[3]-stds[3], alpha=0.1)
plt.plot(np.arange(len(means[4])),  means[4], label='Binomial, p=0.5')
plt.fill_between(np.arange(len(means[4])), means[4]+stds[4], means[4]-stds[4], alpha=0.1)
plt.plot(np.arange(len(means[5])),  means[5], label='Binomial, ')
plt.fill_between(np.arange(len(means[5])), means[5]+stds[5], means[5]-stds[5], alpha=0.1)
plt.xlabel('Iteration', fontsize=14)
plt.ylabel('Best point true value', fontsize=14)
plt.legend()
plt.subplot(1,2,2)
# plt.title("Best point value per iteration")
max_f = np.max(agg[1, 0, 3])
min_f = np.min(agg[0, 0, 3])
plt.plot(np.arange(len(means[0]))*agg[0, :, 3].mean().mean()/min_f,  means[0], label='Gaussian, f=100')
plt.fill_between(np.arange(len(means[0]))*agg[0, :, 3].mean().mean()/min_f, means[0]+stds[0], means[0]-stds[0], alpha=0.1)
plt.plot(np.arange(len(means[1]))*agg[1, :, 3].mean().mean()/min_f,  means[1], label='Gaussian, f=200')
plt.fill_between(np.arange(len(means[1]))*agg[1, :, 3].mean().mean()/min_f, means[1]+stds[1], means[1]-stds[1], alpha=0.1)
plt.plot(np.arange(len(means[2]))*agg[2, :, 3].mean().mean()/min_f,  means[2], label='Binomial, f=200')
plt.fill_between(np.arange(len(means[2]))*agg[2, :, 3].mean().mean()/min_f, means[2]+stds[2], means[2]-stds[2], alpha=0.1)
plt.plot(np.arange(len(means[3]))*agg[3, :, 3].mean().mean()/min_f,  means[3], label='Binomial, f=100')
plt.fill_between(np.arange(len(means[3]))*agg[3, :, 3].mean().mean()/min_f, means[3]+stds[3], means[3]-stds[3], alpha=0.1)
plt.plot(np.arange(len(means[4]))*agg[4, :, 3].mean().mean()/min_f,  means[4], label='Binomail, p=0.5')
plt.fill_between(np.arange(len(means[4]))*agg[4, :, 3].mean().mean()/min_f, means[4]+stds[4], means[4]-stds[4], alpha=0.1)
plt.plot(np.arange(len(means[5]))*agg[5, :, 3].mean().mean()/min_f,  means[5], label='Binomial, ')
plt.fill_between(np.arange(len(means[5]))*agg[5, :, 3].mean().mean()/min_f, means[5]+stds[5], means[5]-stds[5], alpha=0.1)
plt.xlabel('Computation resources', fontsize=14)
# plt.yscale('log', nonposy='clip')
# Out:
# Text(0.5,0,'Computation resources')

# %%
tracks = []
for i in range(len(agg)):
    subtracks = []
    for j in range(len(agg[i])):
        argmins = agg[i, j, 1][agg[i, j, 4]]
        values = ackley1(argmins)
        subtracks.append(values)
    tracks.append(subtracks)

# %%
tracks[2]
# Out:
# [array([ 0.92384766,  0.94320204,  0.67576802,  0.93490217,  0.67576802,
#          0.67576802,  0.67576802,  0.9208963 ,  0.72547449,  0.72547449,
#          0.72547449,  0.72547449,  0.72547449,  0.72547449,  0.36405352,
#          0.36405352,  0.36405352,  0.36405352,  0.36405352,  0.36405352,
#          0.36405352,  0.36405352,  0.36405352,  0.36405352,  0.36405352,
#          0.36405352,  0.36405352,  0.36405352,  0.36405352,  0.36405352,
#          0.36405352,  0.36405352,  0.36405352,  0.36405352,  0.36405352,
#          0.36405352,  0.36405352,  0.36405352,  0.36405352,  0.36405352,
#          0.36405352,  0.36405352,  0.36405352,  0.36405352,  0.36405352,
#          0.36405352,  0.36405352,  0.36405352,  0.36405352,  0.36405352]),
#  array([ 0.92384766,  0.92384766,  0.94320303,  0.94320303,  0.94320303,
#          0.94320303,  0.94320303,  0.94320303,  0.94320303,  0.92384766,
#          0.92384766,  0.92814968,  0.92814968,  0.92814968,  0.92814968,
#          0.92814968,  0.92814968,  0.92814968,  0.92814968,  0.92814968,
#          0.92814968,  0.92814968,  0.92814968,  0.92814968,  0.92814968,
#          0.92814968,  0.92814968,  0.92814968,  0.92814968,  0.92814968,
#          0.7784911 ,  0.7784911 ,  0.7784911 ,  0.71576268,  0.71576268,
#          0.71576268,  0.71576268,  0.71576268,  0.71576268,  0.71576268,
#          0.71576268,  0.71576268,  0.71576268,  0.71576268,  0.71576268,
#          0.71576268,  0.71576268,  0.71576268,  0.71576268,  0.71576268]),
#  array([ 0.89586032,  0.9349907 ,  0.9349907 ,  0.9349907 ,  0.9349907 ,
#          0.93436266,  0.93436266,  0.94175147,  0.62237731,  0.62237731,
#          0.62237731,  0.62237731,  0.62237731,  0.62237731,  0.62237731,
#          0.62237731,  0.62237731,  0.62237731,  0.62237731,  0.62237731,
#          0.62237731,  0.62237731,  0.62237731,  0.62237731,  0.62237731,
#          0.62237731,  0.62237731,  0.62237731,  0.62237731,  0.62237731,
#          0.62237731,  0.62237731,  0.62237731,  0.62237731,  0.62237731,
#          0.62237731,  0.62237731,  0.62237731,  0.62237731,  0.62237731,
#          0.62237731,  0.62237731,  0.62237731,  0.62237731,  0.62237731,
#          0.62237731,  0.41419892,  0.41419892,  0.41419892,  0.41419892]),
#  array([ 0.92384766,  0.94320204,  0.94320204,  0.94320204,  0.94320204,
#          0.94320204,  0.94320204,  0.94320204,  0.94320204,  0.94320204,
#          0.94286908,  0.93795554,  0.93795554,  0.94320148,  0.93795554,
#          0.93795554,  0.93795554,  0.93795554,  0.93795554,  0.93795554,
#          0.93795554,  0.68517164,  0.68517164,  0.68517164,  0.68517164,
#          0.68517164,  0.68517164,  0.68517164,  0.68517164,  0.68517164,
#          0.68517164,  0.68517164,  0.68517164,  0.68517164,  0.68517164,
#          0.68517164,  0.62797644,  0.62797644,  0.34783317,  0.34783317,
#          0.34783317,  0.34783317,  0.34783317,  0.34783317,  0.34783317,
#          0.34783317,  0.34783317,  0.34783317,  0.34783317,  0.34783317]),
#  array([ 0.92384766,  0.93885888,  0.93885888,  0.93885888,  0.65020935,
#          0.65020935,  0.79432545,  0.65020935,  0.65020935,  0.65020935,
#          0.65020935,  0.65020935,  0.65020935,  0.65020935,  0.65020935,
#          0.65020935,  0.65020935,  0.65020935,  0.65020935,  0.65020935,
#          0.42914832,  0.42914832,  0.42914832,  0.42914832,  0.42914832,
#          0.42914832,  0.42914832,  0.42914832,  0.42914832,  0.42914832,
#          0.42914832,  0.42914832,  0.42914832,  0.42914832,  0.42914832,
#          0.42914832,  0.42914832,  0.42914832,  0.42914832,  0.42914832,
#          0.42914832,  0.42914832,  0.42914832,  0.42914832,  0.42914832,
#          0.42914832,  0.42914832,  0.42914832,  0.42914832,  0.42914832]),
#  array([ 0.92384766,  0.94320204,  0.94320204,  0.94320204,  0.94320204,
#          0.94320204,  0.94320204,  0.94320204,  0.94320204,  0.94320204,
#          0.94320204,  0.94320204,  0.92384766,  0.94320204,  0.94320204,
#          0.94320204,  0.92384766,  0.92384766,  0.92384766,  0.92384766,
#          0.9374488 ,  0.9374488 ,  0.92631235,  0.92631235,  0.92631235,
#          0.92631235,  0.92631235,  0.91266383,  0.91266383,  0.91266383,
#          0.91266383,  0.91266383,  0.91266383,  0.91266383,  0.91905715,
#          0.91905715,  0.91905715,  0.91905715,  0.91905715,  0.91905715,
#          0.91905715,  0.91905715,  0.91266383,  0.94052393,  0.94052393,
#          0.94052393,  0.78644045,  0.78644045,  0.78644045,  0.78644045]),
#  array([ 0.92384766,  0.94159347,  0.91165783,  0.91165783,  0.91165783,
#          0.90908744,  0.90908744,  0.90908744,  0.90908744,  0.93508249,
#          0.93508249,  0.93508249,  0.93508249,  0.93508249,  0.93508249,
#          0.67896659,  0.67896659,  0.67896659,  0.67896659,  0.67896659,
#          0.67896659,  0.66122649,  0.66122649,  0.66122649,  0.66122649,
#          0.66122649,  0.66122649,  0.66122649,  0.66122649,  0.66122649,
#          0.66122649,  0.66122649,  0.66122649,  0.66122649,  0.67896659,
#          0.67896659,  0.67896659,  0.22672898,  0.46449687,  0.22672898,
#          0.22672898,  0.22672898,  0.22672898,  0.22672898,  0.22672898,
#          0.22672898,  0.22672898,  0.22672898,  0.22672898,  0.22672898]),
#  array([ 0.92384766,  0.90187162,  0.90187162,  0.92778945,  0.92778945,
#          0.92778945,  0.92778945,  0.92778945,  0.92778945,  0.93838267,
#          0.93838267,  0.93838267,  0.93838267,  0.93838267,  0.36829112,
#          0.36829112,  0.36829112,  0.36829112,  0.36829112,  0.36829112,
#          0.36829112,  0.36829112,  0.36829112,  0.36829112,  0.36829112,
#          0.36829112,  0.36829112,  0.36829112,  0.36829112,  0.36829112,
#          0.36829112,  0.36829112,  0.36829112,  0.36829112,  0.36829112,
#          0.36829112,  0.36829112,  0.36829112,  0.36829112,  0.36829112,
#          0.36829112,  0.36829112,  0.36829112,  0.36829112,  0.36829112,
#          0.36829112,  0.36829112,  0.36829112,  0.36829112,  0.36829112]),
#  array([ 0.92384766,  0.92384766,  0.92384766,  0.93327121,  0.94320382,
#          0.94320418,  0.94320418,  0.94320382,  0.94320382,  0.94320388,
#          0.94320388,  0.94320428,  0.94320428,  0.94320388,  0.94320347,
#          0.94320428,  0.94320428,  0.94320388,  0.94320388,  0.94320193,
#          0.94320193,  0.93327121,  0.93327121,  0.93327121,  0.93941597,
#          0.93327121,  0.77224777,  0.77224777,  0.77224777,  0.77224777,
#          0.77224777,  0.77224777,  0.52913988,  0.52913988,  0.52913988,
#          0.52913988,  0.52913988,  0.52913988,  0.52913988,  0.52913988,
#          0.52913988,  0.52913988,  0.52913988,  0.52913988,  0.52913988,
#          0.52913988,  0.52913988,  0.51307012,  0.51307012,  0.51307012]),
#  array([ 0.9333482 ,  0.9333482 ,  0.9333482 ,  0.9333482 ,  0.94320204,
#          0.94320204,  0.93623831,  0.93623831,  0.93623831,  0.93623831,
#          0.93623831,  0.93623831,  0.9381205 ,  0.94320015,  0.94320015,
#          0.94320015,  0.93623831,  0.94320015,  0.74700517,  0.74700517,
#          0.93051395,  0.74700517,  0.93623831,  0.93623831,  0.93623831,
#          0.93623831,  0.93623831,  0.93623831,  0.93623831,  0.93623831,
#          0.93623831,  0.93623831,  0.93623831,  0.93623831,  0.93623831,
#          0.93623831,  0.93623831,  0.93623831,  0.93623831,  0.93623831,
#          0.93623831,  0.74700517,  0.74700517,  0.93051395,  0.93051395,
#          0.93051395,  0.74700517,  0.93051395,  0.93051395,  0.93051395]),
#  array([ 0.92384766,  0.94320204,  0.94320204,  0.94320204,  0.94320204,
#          0.94320204,  0.94320204,  0.94320204,  0.94320204,  0.94320204,
#          0.94320204,  0.94320204,  0.94320204,  0.94320204,  0.81869079,
#          0.91777196,  0.81869079,  0.58136647,  0.58136647,  0.58136647,
#          0.58136647,  0.58136647,  0.58136647,  0.58136647,  0.58136647,
#          0.58136647,  0.58136647,  0.58136647,  0.58136647,  0.58136647,
#          0.58136647,  0.58136647,  0.58136647,  0.58136647,  0.58136647,
#          0.58136647,  0.58136647,  0.58136647,  0.58136647,  0.58136647,
#          0.58136647,  0.58136647,  0.58136647,  0.58136647,  0.58136647,
#          0.58136647,  0.58136647,  0.58136647,  0.58136647,  0.58136647]),
#  array([ 0.92384766,  0.92384766,  0.91285426,  0.91285426,  0.91285426,
#          0.91285426,  0.91285426,  0.91285426,  0.91285426,  0.82725453,
#          0.82725453,  0.94320227,  0.68088927,  0.68088927,  0.68088927,
#          0.68088927,  0.68088927,  0.68088927,  0.68088927,  0.68088927,
#          0.68088927,  0.68088927,  0.65239013,  0.65239013,  0.65239013,
#          0.65239013,  0.65239013,  0.65239013,  0.65239013,  0.65239013,
#          0.65239013,  0.65239013,  0.65239013,  0.65239013,  0.53160776,
#          0.53160776,  0.53160776,  0.53160776,  0.53160776,  0.53160776,
#          0.53160776,  0.53160776,  0.53160776,  0.53160776,  0.53160776,
#          0.53160776,  0.53160776,  0.53160776,  0.53160776,  0.53160776]),
#  array([ 0.92384766,  0.89985364,  0.89985364,  0.89985364,  0.89985364,
#          0.89985364,  0.89985364,  0.89985364,  0.89985364,  0.89985364,
#          0.89985364,  0.89985364,  0.92954331,  0.92954331,  0.92954331,
#          0.94001118,  0.94001118,  0.94001118,  0.94001118,  0.94001118,
#          0.94001118,  0.94001118,  0.77726212,  0.77726212,  0.94001118,
#          0.94001118,  0.94001118,  0.94001118,  0.94001118,  0.65322913,
#          0.65322913,  0.65322913,  0.65322913,  0.31830734,  0.31830734,
#          0.31830734,  0.31830734,  0.31830734,  0.31830734,  0.31830734,
#          0.31830734,  0.31830734,  0.31830734,  0.31830734,  0.26579346,
#          0.26579346,  0.26579346,  0.26579346,  0.26579346,  0.26579346]),
#  array([ 0.92384766,  0.90983571,  0.90996595,  0.89947422,  0.93497112,
#          0.93497112,  0.93497112,  0.93497112,  0.93497112,  0.93497112,
#          0.93497112,  0.93497112,  0.93607513,  0.93607513,  0.79850379,
#          0.79850379,  0.79850379,  0.79850379,  0.79850379,  0.79850379,
#          0.79850379,  0.79850379,  0.79850379,  0.79850379,  0.79850379,
#          0.79850379,  0.79850379,  0.79850379,  0.79850379,  0.79850379,
#          0.79850379,  0.79850379,  0.79850379,  0.79850379,  0.79850379,
#          0.79850379,  0.61568412,  0.61568412,  0.61568412,  0.61568412,
#          0.61568412,  0.61568412,  0.61789344,  0.61789344,  0.61789344,
#          0.61789344,  0.61789344,  0.61789344,  0.61789344,  0.61789344]),
#  array([ 0.92384766,  0.92384766,  0.92384766,  0.21102216,  0.21102216,
#          0.21102216,  0.21102216,  0.21102216,  0.21102216,  0.21102216,
#          0.21102216,  0.21102216,  0.21102216,  0.21102216,  0.21102216,
#          0.21102216,  0.21102216,  0.21102216,  0.21102216,  0.21102216,
#          0.21102216,  0.21102216,  0.21102216,  0.21102216,  0.21102216,
#          0.21102216,  0.21102216,  0.21102216,  0.21102216,  0.21102216,
#          0.21102216,  0.21102216,  0.21102216,  0.21102216,  0.21102216,
#          0.12158607,  0.12158607,  0.12158607,  0.12158607,  0.12158607,
#          0.12158607,  0.12158607,  0.12158607,  0.12158607,  0.12158607,
#          0.12158607,  0.12158607,  0.12158607,  0.12158607,  0.12158607]),
#  array([ 0.92384766,  0.92384766,  0.92384766,  0.89754741,  0.89754741,
#          0.92384766,  0.89754741,  0.89754741,  0.89754741,  0.89754741,
#          0.92932766,  0.92932766,  0.92932766,  0.92710522,  0.92710522,
#          0.92710522,  0.92710522,  0.92710522,  0.92710522,  0.92710522,
#          0.92710522,  0.92710522,  0.92710522,  0.92710522,  0.92710522,
#          0.73338064,  0.73338064,  0.73338064,  0.73338064,  0.73338064,
#          0.73338064,  0.73338064,  0.73338064,  0.73338064,  0.73338064,
#          0.44585623,  0.44585623,  0.44585623,  0.44585623,  0.44585623,
#          0.44585623,  0.44585623,  0.44585623,  0.44585623,  0.44585623,
#          0.44585623,  0.44585623,  0.44585623,  0.44585623,  0.44585623]),
#  array([ 0.92384766,  0.92384766,  0.92384766,  0.9380779 ,  0.9380779 ,
#          0.9380779 ,  0.9380779 ,  0.9380779 ,  0.9380779 ,  0.9380779 ,
#          0.9380779 ,  0.9380779 ,  0.9380779 ,  0.9380779 ,  0.9380779 ,
#          0.9380779 ,  0.9380779 ,  0.9380779 ,  0.70898268,  0.70898268,
#          0.70898268,  0.70898268,  0.52015949,  0.52015949,  0.52015949,
#          0.52015949,  0.52015949,  0.52015949,  0.52015949,  0.52015949,
#          0.52015949,  0.52015949,  0.52015949,  0.52015949,  0.52015949,
#          0.52015949,  0.52015949,  0.52015949,  0.52015949,  0.52015949,
#          0.52015949,  0.52015949,  0.52015949,  0.52015949,  0.52015949,
#          0.52015949,  0.52015949,  0.52015949,  0.52015949,  0.52015949]),
#  array([ 0.92384766,  0.92384766,  0.92384766,  0.92384766,  0.9431957 ,
#          0.933712  ,  0.94320204,  0.94320204,  0.94320204,  0.94320204,
#          0.94320204,  0.94320204,  0.93994006,  0.93994006,  0.93994006,
#          0.93994006,  0.93994006,  0.93994006,  0.93994006,  0.93994006,
#          0.93994006,  0.93994006,  0.93994006,  0.93994006,  0.93994006,
#          0.93994006,  0.93994006,  0.93994006,  0.93994006,  0.93994006,
#          0.93994006,  0.93994006,  0.93994006,  0.93994006,  0.93994006,
#          0.34287801,  0.34287801,  0.34287801,  0.34287801,  0.34287801,
#          0.34287801,  0.34287801,  0.34287801,  0.34287801,  0.34287801,
#          0.34287801,  0.34287801,  0.34287801,  0.50072144,  0.50072144]),
#  array([ 0.92384766,  0.92384766,  0.92384766,  0.92384766,  0.94283037,
#          0.92384766,  0.92384766,  0.82950073,  0.94067466,  0.94067466,
#          0.94067466,  0.94067466,  0.94320204,  0.92713732,  0.92713732,
#          0.92713732,  0.85797667,  0.85797667,  0.85797667,  0.82950073,
#          0.87560759,  0.87560759,  0.59112337,  0.59112337,  0.59112337,
#          0.59112337,  0.59112337,  0.59112337,  0.59112337,  0.59112337,
#          0.59112337,  0.59112337,  0.59112337,  0.59112337,  0.59112337,
#          0.59112337,  0.59112337,  0.59112337,  0.59112337,  0.59112337,
#          0.59112337,  0.59112337,  0.59112337,  0.59112337,  0.59112337,
#          0.59112337,  0.59112337,  0.59112337,  0.59112337,  0.59112337]),
#  array([ 0.92384766,  0.92384766,  0.9305638 ,  0.9305638 ,  0.92753204,
#          0.92432788,  0.92753204,  0.92753204,  0.92753204,  0.92753204,
#          0.92753204,  0.92753204,  0.92753204,  0.92753204,  0.92753204,
#          0.92753204,  0.92753204,  0.92753204,  0.92753204,  0.94320204,
#          0.94320204,  0.94320204,  0.94320204,  0.94320204,  0.94320204,
#          0.94320204,  0.9422239 ,  0.9422239 ,  0.64263893,  0.64263893,
#          0.64263893,  0.52768565,  0.52768565,  0.52768565,  0.52768565,
#          0.52768565,  0.52768565,  0.52768565,  0.52768565,  0.52768565,
#          0.52768565,  0.52768565,  0.52768565,  0.52768565,  0.52768565,
#          0.52768565,  0.52768565,  0.52768565,  0.52768565,  0.52768565]),
#  array([ 0.92706648,  0.94320204,  0.90910755,  0.94320204,  0.94320204,
#          0.94320204,  0.94320204,  0.94320204,  0.94320204,  0.94320204,
#          0.94320204,  0.94320204,  0.94320204,  0.90910755,  0.90910755,
#          0.90910755,  0.90910755,  0.90910755,  0.92706648,  0.92706648,
#          0.92706648,  0.92706648,  0.92706648,  0.90910755,  0.90910755,
#          0.90910755,  0.90910755,  0.92706648,  0.92706648,  0.92706648,
#          0.92706648,  0.92706648,  0.92706648,  0.92706648,  0.92706648,
#          0.92706648,  0.92706648,  0.92706648,  0.93469463,  0.93469463,
#          0.93469463,  0.93469463,  0.93469463,  0.93469463,  0.93469463,
#          0.93469463,  0.93469463,  0.93469463,  0.93469463,  0.93469463]),
#  array([ 0.92384766,  0.92384766,  0.92384766,  0.92384766,  0.92384766,
#          0.92384766,  0.92384766,  0.92384766,  0.92384766,  0.9293535 ,
#          0.9293535 ,  0.94035623,  0.94035623,  0.94035623,  0.94035623,
#          0.94035623,  0.94077557,  0.94077557,  0.94077557,  0.94077557,
#          0.94077557,  0.94077557,  0.94077557,  0.94077557,  0.94077557,
#          0.94077557,  0.94077557,  0.94077557,  0.94077557,  0.94077557,
#          0.92384766,  0.77075867,  0.92384766,  0.92384766,  0.92384766,
#          0.92384766,  0.92384766,  0.92384766,  0.92384766,  0.92384766,
#          0.92384766,  0.92384766,  0.92384766,  0.9293535 ,  0.9293535 ,
#          0.94077557,  0.81032465,  0.81032465,  0.81032465,  0.77075867]),
#  array([ 0.92384766,  0.75940023,  0.94286248,  0.9354356 ,  0.75940023,
#          0.75940023,  0.75940023,  0.75940023,  0.75940023,  0.75940023,
#          0.75940023,  0.67851764,  0.67851764,  0.61265892,  0.61265892,
#          0.61265892,  0.61265892,  0.61265892,  0.61265892,  0.61265892,
#          0.61265892,  0.61265892,  0.61265892,  0.61265892,  0.61265892,
#          0.61265892,  0.61265892,  0.61265892,  0.61265892,  0.61265892,
#          0.61265892,  0.61265892,  0.61265892,  0.61265892,  0.61265892,
#          0.61265892,  0.61265892,  0.61265892,  0.61265892,  0.61265892,
#          0.61265892,  0.61265892,  0.61265892,  0.61265892,  0.61265892,
#          0.61265892,  0.61265892,  0.61265892,  0.61265892,  0.61265892]),
#  array([ 0.92384766,  0.93424334,  0.93424334,  0.92384766,  0.92384766,
#          0.94320204,  0.94320204,  0.94320204,  0.94320204,  0.94320204,
#          0.94320204,  0.94320204,  0.94320327,  0.94320327,  0.94320327,
#          0.94320327,  0.94320327,  0.94320204,  0.94320204,  0.94320204,
#          0.70144778,  0.93211296,  0.70144778,  0.70144778,  0.70144778,
#          0.70144778,  0.70144778,  0.70144778,  0.70144778,  0.70144778,
#          0.70144778,  0.70144778,  0.70144778,  0.70144778,  0.70144778,
#          0.70144778,  0.70144778,  0.70144778,  0.70144778,  0.70144778,
#          0.70144778,  0.70144778,  0.70144778,  0.70144778,  0.70144778,
#          0.70144778,  0.70144778,  0.70144778,  0.70144778,  0.70144778]),
#  array([ 0.92384766,  0.94320204,  0.83966498,  0.83966498,  0.91341067,
#          0.83966498,  0.93358932,  0.93358932,  0.93358932,  0.93358932,
#          0.93358932,  0.93358932,  0.93358932,  0.93358932,  0.93358932,
#          0.93358932,  0.93358932,  0.93358932,  0.93358932,  0.93358932,
#          0.93358932,  0.93358932,  0.93358932,  0.93358932,  0.93358932,
#          0.93358932,  0.93358932,  0.93358932,  0.93358932,  0.93358932,
#          0.93358932,  0.93358932,  0.93358932,  0.93358932,  0.72027948,
#          0.72027948,  0.72027948,  0.72027948,  0.72027948,  0.72027948,
#          0.72027948,  0.72027948,  0.72027948,  0.64814443,  0.64814443,
#          0.64814443,  0.64814443,  0.64814443,  0.64814443,  0.33472907]),
#  array([ 0.92384766,  0.92384766,  0.92384766,  0.92384766,  0.92384766,
#          0.92384766,  0.92384766,  0.92384766,  0.93293658,  0.93293658,
#          0.93293658,  0.93293658,  0.93293658,  0.93293658,  0.93293658,
#          0.84604534,  0.84676969,  0.84676969,  0.84604534,  0.84604534,
#          0.84604534,  0.84604534,  0.84604534,  0.84604534,  0.84604534,
#          0.84604534,  0.84604534,  0.84604534,  0.84604534,  0.93293658,
#          0.84604534,  0.84604534,  0.84604534,  0.84604534,  0.84604534,
#          0.84604534,  0.84604534,  0.84604534,  0.84604534,  0.84604534,
#          0.84604534,  0.84604534,  0.84604534,  0.84604534,  0.84604534,
#          0.84604534,  0.84604534,  0.51204495,  0.51204495,  0.51204495]),
#  array([ 0.92384766,  0.92384766,  0.92381928,  0.92381928,  0.92381928,
#          0.92381928,  0.92381928,  0.92381928,  0.92381928,  0.92381928,
#          0.92381928,  0.90212951,  0.92071306,  0.92381928,  0.92381928,
#          0.92381928,  0.92071306,  0.92071306,  0.92071306,  0.92071306,
#          0.92071306,  0.92071306,  0.92071306,  0.93705914,  0.92071306,
#          0.92071306,  0.92071306,  0.93299547,  0.93299547,  0.93299547,
#          0.92071306,  0.92071306,  0.93299547,  0.93299547,  0.93299547,
#          0.93299547,  0.93299547,  0.93299547,  0.93299547,  0.93299547,
#          0.6305963 ,  0.6305963 ,  0.6305963 ,  0.6305963 ,  0.6305963 ,
#          0.6305963 ,  0.6305963 ,  0.6305963 ,  0.6305963 ,  0.6305963 ]),
#  array([ 0.92384766,  0.93142298,  0.94318855,  0.92384766,  0.92384766,
#          0.94318855,  0.94320149,  0.94320345,  0.93142298,  0.93142298,
#          0.94320345,  0.94318855,  0.94320345,  0.94320345,  0.94320345,
#          0.94320345,  0.94320345,  0.94320345,  0.94320429,  0.94320429,
#          0.94320429,  0.94320413,  0.94319185,  0.94320345,  0.94320345,
#          0.94320345,  0.94320345,  0.94320345,  0.94320345,  0.94320345,
#          0.94320345,  0.9431017 ,  0.9431017 ,  0.92396804,  0.9431017 ,
#          0.92396804,  0.9431017 ,  0.94320345,  0.9431017 ,  0.94320345,
#          0.94320345,  0.94320345,  0.9431017 ,  0.9431017 ,  0.9431017 ,
#          0.9431017 ,  0.94320345,  0.94320345,  0.94320345,  0.94320345]),
#  array([ 0.92384766,  0.91052145,  0.91052145,  0.91052145,  0.91052145,
#          0.92599989,  0.92599989,  0.92599989,  0.92599989,  0.93055604,
#          0.92599989,  0.92599989,  0.92599989,  0.92599989,  0.92599989,
#          0.93055604,  0.92599989,  0.92599989,  0.92599989,  0.80545404,
#          0.80545404,  0.80545404,  0.80545404,  0.73891137,  0.11589107,
#          0.11589107,  0.11589107,  0.11589107,  0.11589107,  0.11589107,
#          0.11589107,  0.11589107,  0.11589107,  0.11589107,  0.11589107,
#          0.11589107,  0.11589107,  0.11589107,  0.11589107,  0.11589107,
#          0.11589107,  0.11589107,  0.11589107,  0.11589107,  0.11589107,
#          0.11589107,  0.11589107,  0.11589107,  0.11589107,  0.11589107]),
#  array([ 0.92384766,  0.92384766,  0.92384766,  0.93991042,  0.93991042,
#          0.93972595,  0.75106668,  0.77547948,  0.77547948,  0.75106668,
#          0.75106668,  0.75106668,  0.75106668,  0.75106668,  0.75106668,
#          0.75106668,  0.75106668,  0.75106668,  0.75106668,  0.75106668,
#          0.75106668,  0.61039273,  0.61039273,  0.61039273,  0.61039273,
#          0.61039273,  0.61039273,  0.61039273,  0.61039273,  0.61039273,
#          0.61039273,  0.61039273,  0.61039273,  0.61039273,  0.61039273,
#          0.61039273,  0.61039273,  0.61039273,  0.61039273,  0.61039273,
#          0.61039273,  0.61039273,  0.61039273,  0.61039273,  0.61039273,
#          0.61039273,  0.61039273,  0.61039273,  0.61039273,  0.61039273]),
#  array([ 0.93389606,  0.93389606,  0.93389606,  0.93389606,  0.93389606,
#          0.93389606,  0.94320204,  0.94320204,  0.94320204,  0.94320204,
#          0.93389606,  0.93389606,  0.93389606,  0.94320204,  0.93389606,
#          0.93389606,  0.93389606,  0.93389606,  0.82644347,  0.90757669,
#          0.92816907,  0.92816907,  0.92816907,  0.92816907,  0.92816907,
#          0.92816907,  0.92816907,  0.92816907,  0.93389606,  0.77760866,
#          0.77760866,  0.77760866,  0.77760866,  0.77760866,  0.77760866,
#          0.77760866,  0.71685486,  0.71685486,  0.71685486,  0.71685486,
#          0.71685486,  0.71685486,  0.71685486,  0.71685486,  0.71685486,
#          0.71685486,  0.71685486,  0.71685486,  0.54882126,  0.54882126]),
#  array([ 0.92384766,  0.92384766,  0.92384766,  0.89312219,  0.89312219,
#          0.89312219,  0.89312219,  0.89312219,  0.89312219,  0.89312219,
#          0.89312219,  0.89312219,  0.89312219,  0.87834356,  0.87834356,
#          0.93535343,  0.93767809,  0.93767809,  0.93767809,  0.93767809,
#          0.93767809,  0.93767809,  0.93767809,  0.35714505,  0.35714505,
#          0.35714505,  0.35714505,  0.35714505,  0.35714505,  0.35714505,
#          0.35714505,  0.35714505,  0.35714505,  0.35714505,  0.35714505,
#          0.35714505,  0.35714505,  0.35714505,  0.35714505,  0.35714505,
#          0.35714505,  0.35714505,  0.35714505,  0.35714505,  0.35714505,
#          0.35714505,  0.35714505,  0.35714505,  0.35714505,  0.35714505]),
#  array([ 0.92384766,  0.92384766,  0.93989578,  0.93989578,  0.93989578,
#          0.94066803,  0.82616833,  0.82616833,  0.82616833,  0.82616833,
#          0.27942838,  0.27942838,  0.27942838,  0.27942838,  0.27942838,
#          0.27942838,  0.27942838,  0.28460875,  0.28460875,  0.28460875,
#          0.28460875,  0.28460875,  0.28460875,  0.27942838,  0.27942838,
#          0.27942838,  0.27942838,  0.27942838,  0.27942838,  0.27942838,
#          0.27942838,  0.27942838,  0.27942838,  0.27942838,  0.27942838,
#          0.27942838,  0.27942838,  0.27942838,  0.27942838,  0.27942838,
#          0.27942838,  0.27942838,  0.27942838,  0.27942838,  0.27942838,
#          0.27942838,  0.27942838,  0.27942838,  0.27942838,  0.27942838]),
#  array([ 0.92384766,  0.94302773,  0.850888  ,  0.94314286,  0.850888  ,
#          0.92384766,  0.92384766,  0.69030985,  0.69030985,  0.91003607,
#          0.69030985,  0.69030985,  0.79329286,  0.69030985,  0.69030985,
#          0.69030985,  0.69030985,  0.58169416,  0.58169416,  0.56840945,
#          0.56840945,  0.56840945,  0.56840945,  0.56840945,  0.56840945,
#          0.56840945,  0.56840945,  0.56840945,  0.56840945,  0.56840945,
#          0.56840945,  0.56840945,  0.56840945,  0.56840945,  0.56840945,
#          0.58169416,  0.58169416,  0.58169416,  0.58169416,  0.58169416,
#          0.56840945,  0.56840945,  0.56840945,  0.56840945,  0.56840945,
#          0.56840945,  0.56840945,  0.56840945,  0.56840945,  0.56840945]),
#  array([ 0.9172609 ,  0.9172609 ,  0.94320204,  0.94320204,  0.94320204,
#          0.94320204,  0.94320204,  0.94320204,  0.47612409,  0.47612409,
#          0.47612409,  0.47612409,  0.47612409,  0.47612409,  0.47612409,
#          0.47612409,  0.47612409,  0.47612409,  0.47612409,  0.47612409,
#          0.47612409,  0.47612409,  0.47612409,  0.47612409,  0.47612409,
#          0.47612409,  0.47612409,  0.47612409,  0.47612409,  0.47612409,
#          0.47612409,  0.47612409,  0.47612409,  0.47612409,  0.47612409,
#          0.36969882,  0.36969882,  0.36969882,  0.36969882,  0.36969882,
#          0.36969882,  0.36969882,  0.36969882,  0.36969882,  0.36969882,
#          0.36969882,  0.36969882,  0.36969882,  0.36969882,  0.36969882]),
#  array([ 0.92384766,  0.84192468,  0.92756566,  0.90560525,  0.90560525,
#          0.92756566,  0.90560525,  0.92756566,  0.92756566,  0.92006674,
#          0.92006674,  0.92006674,  0.92006674,  0.92006674,  0.92006674,
#          0.78917532,  0.94318867,  0.78917532,  0.71044818,  0.71044818,
#          0.71044818,  0.71044818,  0.44427778,  0.44427778,  0.44427778,
#          0.44427778,  0.44427778,  0.44427778,  0.44427778,  0.44427778,
#          0.44427778,  0.44427778,  0.44427778,  0.44427778,  0.44427778,
#          0.44427778,  0.44427778,  0.44427778,  0.44427778,  0.44427778,
#          0.44427778,  0.44427778,  0.44427778,  0.44427778,  0.44427778,
#          0.44427778,  0.44427778,  0.44427778,  0.44427778,  0.44427778]),
#  array([ 0.93924026,  0.93924026,  0.93924026,  0.87144597,  0.93271223,
#          0.93271223,  0.93271223,  0.93271223,  0.93271223,  0.93271223,
#          0.93271223,  0.93271223,  0.93271223,  0.93271223,  0.93271223,
#          0.93271223,  0.93271223,  0.93271223,  0.93271223,  0.93271223,
#          0.93271223,  0.93271223,  0.93271223,  0.93271223,  0.93856621,
#          0.93856621,  0.93856621,  0.93856621,  0.93856621,  0.93856621,
#          0.93856621,  0.93856621,  0.93856621,  0.93856621,  0.93856621,
#          0.88929614,  0.88929614,  0.88929614,  0.88929614,  0.79686069,
#          0.79686069,  0.79686069,  0.79686069,  0.79686069,  0.79686069,
#          0.79686069,  0.79686069,  0.79686069,  0.79686069,  0.79686069]),
#  array([ 0.90298626,  0.9402065 ,  0.9402065 ,  0.9402065 ,  0.9402065 ,
#          0.9402065 ,  0.9402065 ,  0.93225553,  0.9402065 ,  0.9402065 ,
#          0.9402065 ,  0.9402065 ,  0.9402065 ,  0.94320204,  0.94320204,
#          0.94320204,  0.93225553,  0.9402065 ,  0.9402065 ,  0.9402065 ,
#          0.9402065 ,  0.93225553,  0.9402065 ,  0.94273401,  0.94273401,
#          0.94273401,  0.94273401,  0.94273401,  0.94273401,  0.94273401,
#          0.9402065 ,  0.9402065 ,  0.9402065 ,  0.9402065 ,  0.9402065 ,
#          0.9402065 ,  0.9402065 ,  0.9402065 ,  0.9402065 ,  0.9402065 ,
#          0.9402065 ,  0.9402065 ,  0.9402065 ,  0.9402065 ,  0.9402065 ,
#          0.58465041,  0.58465041,  0.58465041,  0.58465041,  0.58465041]),
#  array([ 0.92384766,  0.94320204,  0.92384766,  0.90934628,  0.90934628,
#          0.90934628,  0.90934628,  0.92766745,  0.92766745,  0.92766745,
#          0.92766745,  0.92766745,  0.92766745,  0.9400767 ,  0.83090025,
#          0.83090025,  0.83090025,  0.83090025,  0.83090025,  0.9400767 ,
#          0.49950699,  0.49950699,  0.8535262 ,  0.49950699,  0.49950699,
#          0.49950699,  0.49950699,  0.57322205,  0.49950699,  0.49950699,
#          0.49950699,  0.49950699,  0.49950699,  0.49950699,  0.49950699,
#          0.49950699,  0.49950699,  0.49950699,  0.49950699,  0.49950699,
#          0.49950699,  0.49950699,  0.49950699,  0.49950699,  0.49950699,
#          0.49950699,  0.49950699,  0.49950699,  0.49950699,  0.49950699]),
#  array([ 0.92384766,  0.92384766,  0.92384766,  0.93089299,  0.53364598,
#          0.90759885,  0.53364598,  0.53364598,  0.53364598,  0.44583696,
#          0.44583696,  0.44583696,  0.44583696,  0.44583696,  0.44583696,
#          0.44583696,  0.44583696,  0.44583696,  0.26903984,  0.40261146,
#          0.40261146,  0.40261146,  0.40261146,  0.26903984,  0.26903984,
#          0.26903984,  0.26903984,  0.26903984,  0.26903984,  0.26903984,
#          0.26903984,  0.26903984,  0.26903984,  0.26903984,  0.26903984,
#          0.26903984,  0.40261146,  0.40261146,  0.40261146,  0.40261146,
#          0.40261146,  0.40261146,  0.40261146,  0.40261146,  0.40261146,
#          0.40261146,  0.40261146,  0.40261146,  0.40261146,  0.40261146]),
#  array([ 0.93044707,  0.93044707,  0.93044707,  0.93044707,  0.93044707,
#          0.93044707,  0.94320298,  0.94320298,  0.94320298,  0.94320298,
#          0.92955823,  0.92955823,  0.92955823,  0.92955823,  0.92955823,
#          0.92955823,  0.92955823,  0.92955823,  0.92955823,  0.92955823,
#          0.92955823,  0.92955823,  0.92955823,  0.92955823,  0.92955823,
#          0.92955823,  0.92955823,  0.92955823,  0.92955823,  0.92955823,
#          0.92955823,  0.92955823,  0.92955823,  0.92955823,  0.92955823,
#          0.92955823,  0.92955823,  0.92955823,  0.92955823,  0.92955823,
#          0.92955823,  0.92955823,  0.92955823,  0.92955823,  0.92955823,
#          0.92955823,  0.92955823,  0.92955823,  0.92955823,  0.92955823]),
#  array([ 0.9244173 ,  0.9244173 ,  0.9244173 ,  0.9244173 ,  0.9244173 ,
#          0.9244173 ,  0.9244173 ,  0.9244173 ,  0.9244173 ,  0.9244173 ,
#          0.9244173 ,  0.94050072,  0.94050072,  0.94050072,  0.94050072,
#          0.94050072,  0.94050072,  0.94050072,  0.94050072,  0.94050072,
#          0.94050072,  0.94050072,  0.94050072,  0.94050072,  0.94050072,
#          0.94050072,  0.94050072,  0.94050072,  0.85349312,  0.85349312,
#          0.85349312,  0.85349312,  0.85349312,  0.85349312,  0.88434466,
#          0.88434466,  0.85349312,  0.85349312,  0.94050072,  0.88434466,
#          0.88434466,  0.88434466,  0.88434466,  0.88434466,  0.88434466,
#          0.88434466,  0.88434466,  0.85349312,  0.88434466,  0.88434466]),
#  array([ 0.92384766,  0.92384766,  0.94296486,  0.93385966,  0.79754866,
#          0.79754866,  0.79754866,  0.79754866,  0.79754866,  0.79754866,
#          0.79754866,  0.79754866,  0.79754866,  0.79754866,  0.79754866,
#          0.56023298,  0.56023298,  0.56023298,  0.56023298,  0.56023298,
#          0.56023298,  0.56023298,  0.56023298,  0.56023298,  0.56023298,
#          0.56023298,  0.5639256 ,  0.5639256 ,  0.5639256 ,  0.5639256 ,
#          0.5639256 ,  0.5639256 ,  0.5639256 ,  0.5639256 ,  0.5639256 ,
#          0.5639256 ,  0.5639256 ,  0.5639256 ,  0.5639256 ,  0.5639256 ,
#          0.5639256 ,  0.5639256 ,  0.5639256 ,  0.5639256 ,  0.5639256 ,
#          0.5639256 ,  0.5639256 ,  0.5639256 ,  0.5639256 ,  0.5639256 ]),
#  array([ 0.92384766,  0.94320307,  0.92384766,  0.92384766,  0.92384766,
#          0.92384766,  0.92384766,  0.92384766,  0.92384766,  0.92153762,
#          0.92153762,  0.92946016,  0.93404258,  0.93404258,  0.93404258,
#          0.93404258,  0.93404258,  0.93404258,  0.93404258,  0.92946016,
#          0.92946016,  0.92946016,  0.92946016,  0.92946016,  0.92946016,
#          0.92946016,  0.92946016,  0.92946016,  0.92946016,  0.92946016,
#          0.92946016,  0.92946016,  0.92946016,  0.92946016,  0.92946016,
#          0.93404258,  0.93404258,  0.93404258,  0.92946016,  0.77207617,
#          0.77207617,  0.77207617,  0.77207617,  0.77207617,  0.77207617,
#          0.77207617,  0.92086429,  0.93404258,  0.8777531 ,  0.8777531 ]),
#  array([ 0.85459269,  0.93600539,  0.93600539,  0.93600539,  0.93600539,
#          0.93600539,  0.93600539,  0.93600539,  0.93600539,  0.93600539,
#          0.93600539,  0.93600539,  0.93600539,  0.93600539,  0.93600539,
#          0.93600539,  0.93600539,  0.85459269,  0.85459269,  0.85459269,
#          0.85459269,  0.8559537 ,  0.8559537 ,  0.8559537 ,  0.8559537 ,
#          0.8559537 ,  0.8559537 ,  0.8559537 ,  0.8559537 ,  0.8559537 ,
#          0.8559537 ,  0.73492146,  0.73492146,  0.73492146,  0.73492146,
#          0.73492146,  0.73492146,  0.73492146,  0.73492146,  0.73492146,
#          0.73492146,  0.73492146,  0.73492146,  0.73492146,  0.73492146,
#          0.73492146,  0.73492146,  0.73492146,  0.73492146,  0.73492146]),
#  array([ 0.92384766,  0.92384766,  0.92691656,  0.93800979,  0.94320204,
#          0.94320204,  0.94320204,  0.94320204,  0.94320204,  0.94320204,
#          0.94320204,  0.94320204,  0.94320204,  0.94319303,  0.94320204,
#          0.94320204,  0.94320204,  0.94320204,  0.94320204,  0.94319303,
#          0.94320204,  0.94320204,  0.94320204,  0.94319303,  0.94319303,
#          0.94319303,  0.94319303,  0.94319303,  0.94319303,  0.94319303,
#          0.94319303,  0.94319303,  0.92691656,  0.93800979,  0.93800979,
#          0.93800979,  0.93800979,  0.93800979,  0.93800979,  0.93800979,
#          0.93800979,  0.93800979,  0.74159783,  0.74159783,  0.74159783,
#          0.74159783,  0.74159783,  0.84639285,  0.74159783,  0.74159783]),
#  array([ 0.90922749,  0.90922749,  0.90922749,  0.90922749,  0.90922749,
#          0.90922749,  0.90922749,  0.90922749,  0.94217347,  0.94217347,
#          0.94217347,  0.94217347,  0.94217347,  0.94217347,  0.72907013,
#          0.72907013,  0.72907013,  0.72907013,  0.72907013,  0.72907013,
#          0.72907013,  0.72907013,  0.72907013,  0.72907013,  0.72907013,
#          0.72907013,  0.72907013,  0.72907013,  0.72907013,  0.25062299,
#          0.25062299,  0.25062299,  0.25062299,  0.25062299,  0.25062299,
#          0.25062299,  0.25062299,  0.25062299,  0.25062299,  0.25062299,
#          0.25062299,  0.25062299,  0.25062299,  0.25062299,  0.25062299,
#          0.25062299,  0.25062299,  0.25062299,  0.25062299,  0.25062299]),
#  array([ 0.92384766,  0.92384766,  0.93352289,  0.94320204,  0.94320204,
#          0.93352289,  0.59422062,  0.59422062,  0.59422062,  0.59422062,
#          0.59422062,  0.59422062,  0.59422062,  0.59422062,  0.59422062,
#          0.48260298,  0.48260298,  0.48260298,  0.48260298,  0.48260298,
#          0.48260298,  0.48260298,  0.48260298,  0.48260298,  0.48260298,
#          0.48260298,  0.48260298,  0.48260298,  0.48260298,  0.48260298,
#          0.48260298,  0.48260298,  0.64270489,  0.48260298,  0.59422062,
#          0.59422062,  0.59422062,  0.59422062,  0.59422062,  0.59422062,
#          0.59422062,  0.59422062,  0.59422062,  0.59422062,  0.59422062,
#          0.59422062,  0.59422062,  0.59422062,  0.59422062,  0.59422062]),
#  array([ 0.93435629,  0.93435629,  0.93435629,  0.93435629,  0.94320204,
#          0.94320204,  0.94320204,  0.94320361,  0.94320361,  0.94320361,
#          0.93435629,  0.93435629,  0.93435629,  0.93435629,  0.93435629,
#          0.93435629,  0.93435629,  0.93435629,  0.93435629,  0.93435629,
#          0.93435629,  0.93435629,  0.93435629,  0.93435629,  0.93435629,
#          0.93435629,  0.93435629,  0.93435629,  0.93435629,  0.93435629,
#          0.93435629,  0.93435629,  0.93435629,  0.93435629,  0.93435629,
#          0.93435629,  0.93435629,  0.93435629,  0.93435629,  0.93435629,
#          0.93435629,  0.93435629,  0.93435629,  0.93435629,  0.93435629,
#          0.93435629,  0.93435629,  0.93435629,  0.77560764,  0.77560764]),
#  array([ 0.92384766,  0.94053139,  0.56075926,  0.56075926,  0.56075926,
#          0.56075926,  0.67284351,  0.56075926,  0.56075926,  0.56075926,
#          0.56075926,  0.56075926,  0.56075926,  0.45993819,  0.45993819,
#          0.56075926,  0.56075926,  0.56075926,  0.56075926,  0.56075926,
#          0.56075926,  0.51413388,  0.51413388,  0.51413388,  0.51413388,
#          0.51413388,  0.51413388,  0.51413388,  0.51413388,  0.51413388,
#          0.51413388,  0.51413388,  0.51413388,  0.51413388,  0.51413388,
#          0.51413388,  0.51413388,  0.51413388,  0.51413388,  0.51413388,
#          0.51413388,  0.51413388,  0.51413388,  0.51413388,  0.51413388,
#          0.51413388,  0.51413388,  0.51413388,  0.51413388,  0.51413388])]

# %%
plt.plot(np.array(tracks[2]).T)
# Out:
# [<matplotlib.lines.Line2D at 0x7f57ee328cf8>,
#  <matplotlib.lines.Line2D at 0x7f57ee328e48>,
#  <matplotlib.lines.Line2D at 0x7f57ee328f98>,
#  <matplotlib.lines.Line2D at 0x7f57ee331128>,
#  <matplotlib.lines.Line2D at 0x7f57ee331278>,
#  <matplotlib.lines.Line2D at 0x7f57ee3313c8>,
#  <matplotlib.lines.Line2D at 0x7f57ee331518>,
#  <matplotlib.lines.Line2D at 0x7f57ee331668>,
#  <matplotlib.lines.Line2D at 0x7f57ee3317b8>,
#  <matplotlib.lines.Line2D at 0x7f57ee331908>,
#  <matplotlib.lines.Line2D at 0x7f57ee308f60>,
#  <matplotlib.lines.Line2D at 0x7f57ee331b70>,
#  <matplotlib.lines.Line2D at 0x7f57ee331cc0>,
#  <matplotlib.lines.Line2D at 0x7f57ee331e10>,
#  <matplotlib.lines.Line2D at 0x7f57ee331f60>,
#  <matplotlib.lines.Line2D at 0x7f57ee3370f0>,
#  <matplotlib.lines.Line2D at 0x7f57ee337240>,
#  <matplotlib.lines.Line2D at 0x7f57ee337390>,
#  <matplotlib.lines.Line2D at 0x7f57ee3374e0>,
#  <matplotlib.lines.Line2D at 0x7f57ee337630>,
#  <matplotlib.lines.Line2D at 0x7f57ee337780>,
#  <matplotlib.lines.Line2D at 0x7f57ee3378d0>,
#  <matplotlib.lines.Line2D at 0x7f57ee337a20>,
#  <matplotlib.lines.Line2D at 0x7f57ee337b70>,
#  <matplotlib.lines.Line2D at 0x7f57ee337cc0>,
#  <matplotlib.lines.Line2D at 0x7f57ee337e10>,
#  <matplotlib.lines.Line2D at 0x7f57ee337f60>,
#  <matplotlib.lines.Line2D at 0x7f57ee33b0f0>,
#  <matplotlib.lines.Line2D at 0x7f57ee33b240>,
#  <matplotlib.lines.Line2D at 0x7f57ee33b390>,
#  <matplotlib.lines.Line2D at 0x7f57ee33b4e0>,
#  <matplotlib.lines.Line2D at 0x7f57ee33b630>,
#  <matplotlib.lines.Line2D at 0x7f57ee33b780>,
#  <matplotlib.lines.Line2D at 0x7f57ee33b8d0>,
#  <matplotlib.lines.Line2D at 0x7f57ee33ba20>,
#  <matplotlib.lines.Line2D at 0x7f57ee33bb70>,
#  <matplotlib.lines.Line2D at 0x7f57ee33bc50>,
#  <matplotlib.lines.Line2D at 0x7f57ee33bda0>,
#  <matplotlib.lines.Line2D at 0x7f57ee33bef0>,
#  <matplotlib.lines.Line2D at 0x7f57ee2c1080>,
#  <matplotlib.lines.Line2D at 0x7f57ee2c11d0>,
#  <matplotlib.lines.Line2D at 0x7f57ee2c1320>,
#  <matplotlib.lines.Line2D at 0x7f57ee2c1470>,
#  <matplotlib.lines.Line2D at 0x7f57ee2c15c0>,
#  <matplotlib.lines.Line2D at 0x7f57ee2c1710>,
#  <matplotlib.lines.Line2D at 0x7f57ee2c1860>,
#  <matplotlib.lines.Line2D at 0x7f57ee2c19b0>,
#  <matplotlib.lines.Line2D at 0x7f57ee2c1b00>,
#  <matplotlib.lines.Line2D at 0x7f57ee2c1c50>,
#  <matplotlib.lines.Line2D at 0x7f57ee2c1da0>]

# %%
plt.hist(np.array(tracks[5])[:, 49])
# Out:
# (array([  1.,   1.,   1.,   1.,   9.,   8.,   6.,  10.,   3.,  10.]),
#  array([ 0.07971858,  0.16604415,  0.25236971,  0.33869528,  0.42502085,
#          0.51134641,  0.59767198,  0.68399755,  0.77032311,  0.85664868,
#          0.94297425]),
#  <a list of 10 Patch objects>)

# %%
max_f = np.max(agg[1, 0, 3])
min_f = np.min(agg[0, 0, 3])
plt.plot(np.arange(len(means[0]))*agg[0, :, 3].mean().mean()/min_f,  means[0], label='Gaussian, f=100')
plt.fill_between(np.arange(len(means[0]))*agg[0, :, 3].mean().mean()/min_f, means[0]+stds[0], means[0]-stds[0], alpha=0.1)
plt.plot(np.arange(len(means[1]))*agg[1, :, 3].mean().mean()/min_f,  means[1], label='Gaussian, f=200')
plt.fill_between(np.arange(len(means[1]))*agg[1, :, 3].mean().mean()/min_f, means[1]+stds[1], means[1]-stds[1], alpha=0.1)
plt.plot(np.arange(len(means[2]))*agg[2, :, 3].mean().mean()/min_f,  means[2], label='Binomial, f=200')
plt.fill_between(np.arange(len(means[2]))*agg[2, :, 3].mean().mean()/min_f, means[2]+stds[2], means[2]-stds[2], alpha=0.1)
plt.plot(np.arange(len(means[3]))*agg[3, :, 3].mean().mean()/min_f,  means[3], label='Binomial, f=100')
plt.fill_between(np.arange(len(means[3]))*agg[3, :, 3].mean().mean()/min_f, means[3]+stds[3], means[3]-stds[3], alpha=0.1)
plt.plot(np.arange(len(means[4]))*agg[4, :, 3].mean().mean()/min_f,  means[4], label='Binomail, p=0.5', ls='--')
plt.fill_between(np.arange(len(means[4]))*agg[4, :, 3].mean().mean()/min_f, means[4]+stds[4], means[4]-stds[4], alpha=0.1)
plt.plot(np.arange(len(means[5]))*agg[5, :, 3].mean().mean()/min_f,  means[5], label='Binomial, p smart', ls='--')
plt.fill_between(np.arange(len(means[5]))*agg[5, :, 3].mean().mean()/min_f, means[5]+stds[5], means[5]-stds[5], alpha=0.1)
plt.xlabel('Computational resources', fontsize=16)
plt.ylabel(r"$\pi(\hat{x}_{min}(t))$", fontsize=16)
plt.title("Ackley1", fontsize=18)
plt.legend()

# %%
# ackley1_1_2_100_200_ind0
max_fidelity = 200
min_fidelity = 100
mean_fidelities = []
for i in range(agg.shape[0]):
    mean_fidelities.append(agg[i, :, 3].mean().mean())

# %%
for i in range(agg.shape[0]):
    idx = int((len(means[i])-1)/mean_fidelities[i]*min_fidelity)
    print(i, means[i][idx], stds[i][idx])
# Out:
# 0 0.925845619154 0.0555324080579
# 1 0.939956150317 0.00311016985673
# 2 0.797286658581 0.225058963566
# 3 0.710328272901 0.229147655197
# 4 0.656823824992 0.223357765457
# 5 0.664740470768 0.270150939414

# %%
means, stds = return_track(agg, michalewicz)

plt.figure(figsize=(15, 5))
plt.suptitle("Michalewicz 2D", fontsize=20)
plt.subplot(1,2,1)
# plt.title("Best point value per iteration", fontsize=18)
plt.plot(np.arange(len(means[0])),  means[0], label='Gaussian, f=100')
plt.fill_between(np.arange(len(means[0])), means[0]+stds[0], means[0]-stds[0], alpha=0.1)
plt.plot(np.arange(len(means[1])),  means[1], label='Gaussian, f=200')
plt.fill_between(np.arange(len(means[1])), means[1]+stds[1], means[1]-stds[1], alpha=0.1)
plt.plot(np.arange(len(means[2])),  means[2], label='Binomial, f=200')
plt.fill_between(np.arange(len(means[2])), means[2]+stds[2], means[2]-stds[2], alpha=0.1)
plt.plot(np.arange(len(means[3])),  means[3], label='Binomial, f=100')
plt.fill_between(np.arange(len(means[3])), means[3]+stds[3], means[3]-stds[3], alpha=0.1)
plt.plot(np.arange(len(means[4])),  means[4], label='Binomial, p=0.5')
plt.fill_between(np.arange(len(means[4])), means[4]+stds[4], means[4]-stds[4], alpha=0.1)
plt.plot(np.arange(len(means[5])),  means[5], label='Binomial, ')
plt.fill_between(np.arange(len(means[5])), means[5]+stds[5], means[5]-stds[5], alpha=0.1)
plt.xlabel('Iteration', fontsize=14)
plt.ylabel('Best point true value', fontsize=14)
plt.legend()
plt.subplot(1,2,2)
# plt.title("Best point value per iteration")
max_f = np.max(agg[1, 0, 3])
min_f = np.min(agg[0, 0, 3])
plt.plot(np.arange(len(means[0]))*agg[0, :, 3].mean().mean()/min_f,  means[0], label='Gaussian, f=100')
plt.fill_between(np.arange(len(means[0]))*agg[0, :, 3].mean().mean()/min_f, means[0]+stds[0], means[0]-stds[0], alpha=0.1)
plt.plot(np.arange(len(means[1]))*agg[1, :, 3].mean().mean()/min_f,  means[1], label='Gaussian, f=200')
plt.fill_between(np.arange(len(means[1]))*agg[1, :, 3].mean().mean()/min_f, means[1]+stds[1], means[1]-stds[1], alpha=0.1)
plt.plot(np.arange(len(means[2]))*agg[2, :, 3].mean().mean()/min_f,  means[2], label='Binomial, f=200')
plt.fill_between(np.arange(len(means[2]))*agg[2, :, 3].mean().mean()/min_f, means[2]+stds[2], means[2]-stds[2], alpha=0.1)
plt.plot(np.arange(len(means[3]))*agg[3, :, 3].mean().mean()/min_f,  means[3], label='Binomial, f=100')
plt.fill_between(np.arange(len(means[3]))*agg[3, :, 3].mean().mean()/min_f, means[3]+stds[3], means[3]-stds[3], alpha=0.1)
plt.plot(np.arange(len(means[4]))*agg[4, :, 3].mean().mean()/min_f,  means[4], label='Binomail, p=0.5')
plt.fill_between(np.arange(len(means[4]))*agg[4, :, 3].mean().mean()/min_f, means[4]+stds[4], means[4]-stds[4], alpha=0.1)
plt.plot(np.arange(len(means[5]))*agg[5, :, 3].mean().mean()/min_f,  means[5], label='Binomial, ')
plt.fill_between(np.arange(len(means[5]))*agg[5, :, 3].mean().mean()/min_f, means[5]+stds[5], means[5]-stds[5], alpha=0.1)
plt.xlabel('Computation resources', fontsize=14)
# plt.yscale('log', nonposy='clip')
# Out:
# Text(0.5,0,'Computation resources')

# %%
max_f = np.max(agg[1, 0, 3])
min_f = np.min(agg[0, 0, 3])
plt.plot(np.arange(len(means[0]))*agg[0, :, 3].mean().mean()/min_f,  means[0], label='Gaussian, f=100')
plt.fill_between(np.arange(len(means[0]))*agg[0, :, 3].mean().mean()/min_f, means[0]+stds[0], means[0]-stds[0], alpha=0.1)
plt.plot(np.arange(len(means[1]))*agg[1, :, 3].mean().mean()/min_f,  means[1], label='Gaussian, f=200')
plt.fill_between(np.arange(len(means[1]))*agg[1, :, 3].mean().mean()/min_f, means[1]+stds[1], means[1]-stds[1], alpha=0.1)
plt.plot(np.arange(len(means[2]))*agg[2, :, 3].mean().mean()/min_f,  means[2], label='Binomial, f=200')
plt.fill_between(np.arange(len(means[2]))*agg[2, :, 3].mean().mean()/min_f, means[2]+stds[2], means[2]-stds[2], alpha=0.1)
plt.plot(np.arange(len(means[3]))*agg[3, :, 3].mean().mean()/min_f,  means[3], label='Binomial, f=100')
plt.fill_between(np.arange(len(means[3]))*agg[3, :, 3].mean().mean()/min_f, means[3]+stds[3], means[3]-stds[3], alpha=0.1)
plt.plot(np.arange(len(means[4]))*agg[4, :, 3].mean().mean()/min_f,  means[4], label='Binomail, p=0.5', ls='--')
plt.fill_between(np.arange(len(means[4]))*agg[4, :, 3].mean().mean()/min_f, means[4]+stds[4], means[4]-stds[4], alpha=0.1)
plt.plot(np.arange(len(means[5]))*agg[5, :, 3].mean().mean()/min_f,  means[5], label='Binomial, p smart', ls='--')
plt.fill_between(np.arange(len(means[5]))*agg[5, :, 3].mean().mean()/min_f, means[5]+stds[5], means[5]-stds[5], alpha=0.1)
plt.xlabel('Computational resources', fontsize=16)
plt.ylabel(r"$\pi(\hat{x}_{min}(t))$", fontsize=16)
plt.title("Michalewicz", fontsize=18)
# plt.legend()
# Out:
# Text(0.5,1,'Michalewicz')

# %%
# 'michalewicz_2_2_100_200_ind4'
max_fidelity = 200
min_fidelity = 100
mean_fidelities = []
for i in range(agg.shape[0]):
    mean_fidelities.append(agg[i, :, 3].mean().mean())

# %%
for i in range(agg.shape[0]):
    idx = int((len(means[i])-1)/mean_fidelities[i]*min_fidelity)
    print(i, means[i][idx], stds[i][idx])
# Out:
# 0 0.362195581441 0.148496520131
# 1 0.377804110404 0.137639964157
# 2 0.11382051104 0.073716455087
# 3 0.0891159986653 0.0387537004018
# 4 0.115822240645 0.0524109405506
# 5 0.125053210628 0.0619236533291

# %%
means, stds = return_track(agg, rosenbrock)

plt.figure(figsize=(15, 5))
plt.suptitle("Rosenbrock 2D", fontsize=20)
plt.subplot(1,2,1)
# plt.title("Best point value per iteration", fontsize=18)
plt.plot(np.arange(len(means[0])),  means[0], label='Gaussian, f=100')
plt.fill_between(np.arange(len(means[0])), means[0]+stds[0], means[0]-stds[0], alpha=0.1)
plt.plot(np.arange(len(means[1])),  means[1], label='Gaussian, f=200')
plt.fill_between(np.arange(len(means[1])), means[1]+stds[1], means[1]-stds[1], alpha=0.1)
plt.plot(np.arange(len(means[2])),  means[2], label='Binomial, f=200')
plt.fill_between(np.arange(len(means[2])), means[2]+stds[2], means[2]-stds[2], alpha=0.1)
plt.plot(np.arange(len(means[3])),  means[3], label='Binomial, f=100')
plt.fill_between(np.arange(len(means[3])), means[3]+stds[3], means[3]-stds[3], alpha=0.1)
plt.plot(np.arange(len(means[4])),  means[4], label='Binomial, p=0.5')
plt.fill_between(np.arange(len(means[4])), means[4]+stds[4], means[4]-stds[4], alpha=0.1)
plt.plot(np.arange(len(means[5])),  means[5], label='Binomial, ')
plt.fill_between(np.arange(len(means[5])), means[5]+stds[5], means[5]-stds[5], alpha=0.1)
plt.xlabel('Iteration', fontsize=14)
plt.ylabel('Best point true value', fontsize=14)
plt.legend()
plt.yscale('log', nonposy='clip')
plt.subplot(1,2,2)
# plt.title("Best point value per iteration")
max_f = np.max(agg[1, 0, 3])
min_f = np.min(agg[0, 0, 3])
plt.plot(np.arange(len(means[0]))*agg[0, :, 3].mean().mean()/min_f,  means[0], label='Gaussian, f=100')
plt.fill_between(np.arange(len(means[0]))*agg[0, :, 3].mean().mean()/min_f, means[0]+stds[0], means[0]-stds[0], alpha=0.1)
plt.plot(np.arange(len(means[1]))*agg[1, :, 3].mean().mean()/min_f,  means[1], label='Gaussian, f=200')
plt.fill_between(np.arange(len(means[1]))*agg[1, :, 3].mean().mean()/min_f, means[1]+stds[1], means[1]-stds[1], alpha=0.1)
plt.plot(np.arange(len(means[2]))*agg[2, :, 3].mean().mean()/min_f,  means[2], label='Binomial, f=200')
plt.fill_between(np.arange(len(means[2]))*agg[2, :, 3].mean().mean()/min_f, means[2]+stds[2], means[2]-stds[2], alpha=0.1)
plt.plot(np.arange(len(means[3]))*agg[3, :, 3].mean().mean()/min_f,  means[3], label='Binomial, f=100')
plt.fill_between(np.arange(len(means[3]))*agg[3, :, 3].mean().mean()/min_f, means[3]+stds[3], means[3]-stds[3], alpha=0.1)
plt.plot(np.arange(len(means[4]))*agg[4, :, 3].mean().mean()/min_f,  means[4], label='Binomail, p=0.5')
plt.fill_between(np.arange(len(means[4]))*agg[4, :, 3].mean().mean()/min_f, means[4]+stds[4], means[4]-stds[4], alpha=0.1)
plt.plot(np.arange(len(means[5]))*agg[5, :, 3].mean().mean()/min_f,  means[5], label='Binomial, ')
plt.fill_between(np.arange(len(means[5]))*agg[5, :, 3].mean().mean()/min_f, means[5]+stds[5], means[5]-stds[5], alpha=0.1)
plt.xlabel('Computation resources', fontsize=14)
plt.yscale('log', nonposy='clip')

# %%
max_f = np.max(agg[1, 0, 3])
min_f = np.min(agg[0, 0, 3])
plt.plot(np.arange(len(means[0]))*agg[0, :, 3].mean().mean()/min_f,  means[0], label='Gaussian, f=100')
plt.fill_between(np.arange(len(means[0]))*agg[0, :, 3].mean().mean()/min_f, means[0]+stds[0], means[0]-stds[0], alpha=0.1)
plt.plot(np.arange(len(means[1]))*agg[1, :, 3].mean().mean()/min_f,  means[1], label='Gaussian, f=200')
plt.fill_between(np.arange(len(means[1]))*agg[1, :, 3].mean().mean()/min_f, means[1]+stds[1], means[1]-stds[1], alpha=0.1)
plt.plot(np.arange(len(means[2]))*agg[2, :, 3].mean().mean()/min_f,  means[2], label='Binomial, f=200')
plt.fill_between(np.arange(len(means[2]))*agg[2, :, 3].mean().mean()/min_f, means[2]+stds[2], means[2]-stds[2], alpha=0.1)
plt.plot(np.arange(len(means[3]))*agg[3, :, 3].mean().mean()/min_f,  means[3], label='Binomial, f=100')
plt.fill_between(np.arange(len(means[3]))*agg[3, :, 3].mean().mean()/min_f, means[3]+stds[3], means[3]-stds[3], alpha=0.1)
plt.plot(np.arange(len(means[4]))*agg[4, :, 3].mean().mean()/min_f,  means[4], label='Binomail, p=0.5', ls='--')
plt.fill_between(np.arange(len(means[4]))*agg[4, :, 3].mean().mean()/min_f, means[4]+stds[4], means[4]-stds[4], alpha=0.1)
plt.plot(np.arange(len(means[5]))*agg[5, :, 3].mean().mean()/min_f,  means[5], label='Binomial, p smart', ls='--')
plt.fill_between(np.arange(len(means[5]))*agg[5, :, 3].mean().mean()/min_f, means[5]+stds[5], means[5]-stds[5], alpha=0.1)
plt.xlabel('Computation resources', fontsize=16)
plt.ylabel(r"$\pi(\hat{x}_{min}(t))$", fontsize=16)
plt.title("Rosenbrock", fontsize=18)
# plt.legend()
# Out:
# Text(0.5,1,'Rosenbrock')

# %%
max_f = np.max(agg[1, 0, 3])
min_f = np.min(agg[0, 0, 3])
plt.plot(np.arange(len(means[0]))*agg[0, :, 3].mean().mean()/min_f,  means[0], label='Gaussian, f=100')
plt.fill_between(np.arange(len(means[0]))*agg[0, :, 3].mean().mean()/min_f, means[0]+stds[0], means[0]-stds[0], alpha=0.1)
plt.plot(np.arange(len(means[1]))*agg[1, :, 3].mean().mean()/min_f,  means[1], label='Gaussian, f=200')
plt.fill_between(np.arange(len(means[1]))*agg[1, :, 3].mean().mean()/min_f, means[1]+stds[1], means[1]-stds[1], alpha=0.1)
plt.plot(np.arange(len(means[2]))*agg[2, :, 3].mean().mean()/min_f,  means[2], label='Binomial, f=200')
plt.fill_between(np.arange(len(means[2]))*agg[2, :, 3].mean().mean()/min_f, means[2]+stds[2], means[2]-stds[2], alpha=0.1)
plt.plot(np.arange(len(means[3]))*agg[3, :, 3].mean().mean()/min_f,  means[3], label='Binomial, f=100')
plt.fill_between(np.arange(len(means[3]))*agg[3, :, 3].mean().mean()/min_f, means[3]+stds[3], means[3]-stds[3], alpha=0.1)
plt.plot(np.arange(len(means[4]))*agg[4, :, 3].mean().mean()/min_f,  means[4], label='Binomail, p=0.5', ls='--')
plt.fill_between(np.arange(len(means[4]))*agg[4, :, 3].mean().mean()/min_f, means[4]+stds[4], means[4]-stds[4], alpha=0.1)
plt.plot(np.arange(len(means[5]))*agg[5, :, 3].mean().mean()/min_f,  means[5], label='Binomial, p smart', ls='--')
plt.fill_between(np.arange(len(means[5]))*agg[5, :, 3].mean().mean()/min_f, means[5]+stds[5], means[5]-stds[5], alpha=0.1)
plt.xlabel('Computational resources', fontsize=16)
plt.ylabel(r"$\pi(\hat{x}_{min}(t))$", fontsize=16)
plt.title("Rosenbrock", fontsize=18)
plt.yscale('log', nonposy='clip')
# plt.legend()

# %%
# rosenbrock_100_2_100_200_ind3
max_fidelity = 200
min_fidelity = 100
mean_fidelities = []
for i in range(agg.shape[0]):
    mean_fidelities.append(agg[i, :, 3].mean().mean())

# %%
for i in range(agg.shape[0]):
    idx = int((len(means[i])-1)/mean_fidelities[i]*min_fidelity)
    print(i, means[i][idx], stds[i][idx])
# Out:
# 0 0.00582554729268 0.0173375466785
# 1 0.00409731547437 0.00334377537313
# 2 2.4392023109e-05 3.25153040127e-05
# 3 4.96407772388e-05 0.000103647443349
# 4 9.80318456086e-05 0.000234658974268
# 5 9.27342393693e-05 0.000161966071297

# %%
df = pd.DataFrame(columns=['method', 'Ackley1', 'Michalewicz', 'Rosenbrock'])
df['method'] = ['Gaussian, f=100', 'Gaussian, f=200', 'Binomial, f=200', 'Binomial, f=100', 'Binomial, p=0.5', 'Binomial, dfid']
df['Ackley1'] = [r'$0.925\pm$ 0.055', r'$0.939\pm$ 0.003', r'$0.797\pm$ 0.225', r'$0.710\pm$ 0.229', r'$0.656\pm$ 0.223', r'$0.664\pm$ 0.270'] 
df['Michalewicz'] = [r'$0.362\pm$ 0.148', r'$0.377\pm$ 0.137', r'$0.113\pm$ 0.073', r'$0.089\pm$ 0.038', r'$0.115\pm$ 0.052', r'$0.125\pm$ 0.0619']
df['Rosenbrock'] = [r'$0.005825\pm$ 0.017337', r'$0.004097\pm$ 0.003343', r'$0.000024\pm$ 0.000032', r'$0.000049\pm$ 0.000103', r'$0.000098\pm$ 0.000234', r'$0.000092\pm$ 0.000161']

# %%
df
# Out:
#             method           Ackley1        Michalewicz  \
# 0  Gaussian, f=100  $0.925\pm$ 0.055   $0.362\pm$ 0.148
# 1  Gaussian, f=200  $0.939\pm$ 0.003   $0.377\pm$ 0.137
# 2  Binomial, f=200  $0.797\pm$ 0.225   $0.113\pm$ 0.073
# 3  Binomial, f=100  $0.710\pm$ 0.229   $0.089\pm$ 0.038
# 4  Binomial, p=0.5  $0.656\pm$ 0.223   $0.115\pm$ 0.052
# 5   Binomial, dfid  $0.664\pm$ 0.270  $0.125\pm$ 0.0619
#
#                Rosenbrock
# 0  $0.005825\pm$ 0.017337
# 1  $0.004097\pm$ 0.003343
# 2  $0.000024\pm$ 0.000032
# 3  $0.000049\pm$ 0.000103
# 4  $0.000098\pm$ 0.000234
# 5  $0.000092\pm$ 0.000161

# %%
0 0.362195581441 0.148496520131
1 0.377804110404 0.137639964157
2 0.11382051104 0.073716455087
3 0.0891159986653 0.0387537004018
4 0.115822240645 0.0524109405506
5 0.125053210628 0.0619236533291

# %%
xs = np.linspace(-bound, bound, 300)
ys = np.linspace(-bound, bound, 300)
xs, ys = np.meshgrid(xs, ys)
values = sqmichalewicz5(np.dstack([xs, ys]).reshape(90000, 2)).reshape(300, 300)
fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(1, 2, 1, projection='3d')
p = ax.plot_surface(xs, ys, values, rstride=4, cstride=4, linewidth=0)
ax.set_xlabel(r"$x_1$", fontsize=22)
ax.set_ylabel(r"$x_2$", fontsize=22)
# ax.set_zlabel(r"$f(x)$", fontsize=22)
print(sqmichalewicz5(argmin.reshape(1, -1)))
# Out:
# [ 0.]

# %%
agg[0, 0, 1][agg[0, 0, 4][5]]
# Out:
# array([-15.26603264,  -0.98100544,  21.18886462, -76.82002005,
#         82.87664782])
