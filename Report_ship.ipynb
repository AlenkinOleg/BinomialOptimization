# %%
import numpy as np
import pandas as pd
import GPy
import GPyOpt
import math
from scipy.optimize import minimize, differential_evolution
from scipy.stats import norm, beta
import matplotlib.pyplot as plt
import pickle

# %matplotlib inline

# %%
import sys
sys.path.append('../ShipOpt2/Comparison')
from binomial_optimization3 import value_generator, optimization_step

# %% [markdown]
# Fit our reference model

# %%
bd = pd.read_csv('../ShipOpt2/PatternRecognitionOptimization/observations/observations_old_settings.csv').dropna()
binomial = GPy.likelihoods.Binomial()

trials_t = np.array(len(bd) * [[500]])
X_t = bd[bd.columns[:-2]].values
Y_t = bd[['reco_passed_no_clones']].values

t_f = GPy.core.GP(X_t, Y_t, kernel=GPy.kern.RBF(7), 
                  Y_metadata={'trials': trials_t},
                  inference_method=GPy.inference.latent_function_inference.laplace.Laplace(),
                  likelihood=binomial)

# %%
t_f.optimize()

# %%
true_function = lambda x: binomial.gp_link.transf(t_f._raw_predict(x)[0])

# %% [markdown]
# # Comparison of GP and GGPM with binomial distribution

# %%
min_dist = 3.6
radius = 2

space = [{'name': 'pitch', 'type': 'continuous', 'domain': (min_dist, min_dist)},\
         {'name': 'yoffset_layer', 'type': 'continuous', 'domain': (min_dist/2, min_dist)},\
         {'name': 'yoffset_plane', 'type': 'continuous', 'domain': (min_dist*0.25, min_dist*1.25)},\
         {'name': 'zshift_layer', 'type': 'continuous', 'domain': (1, 15)},\
         {'name': 'zshift_plane', 'type': 'continuous', 'domain': (1, 15)},\
         {'name': 'zshift_view', 'type': 'continuous', 'domain': (10, 15)},\
         {'name': 'alpha', 'type': 'continuous', 'domain': (5, 15)}]

constraints = [{'name': 'constr_1', 'constrain': '-(x[:,0]-x[:,1])**2-x[:,3]**2+'+str(radius)+'**2'},\
               {'name': 'constr_2', 'constrain': '-(x[:,1]-x[:,2])**2-(x[:,3]-x[:,4])**2+'+str(radius)+'**2'},\
               {'name': 'constr_3', 'constrain': 'x[:,3]+x[:,4]+'+str(radius)+'-x[:,5]'},
               {'name': 'constr_4', 'constrain': 'x[:,3]+'+str(radius)+'-x[:,4]'}]

# %%
n_trials = 100
n_iteration = 60
initial_size = 10

dims = len(space)
feasible_region = GPyOpt.Design_space(space=space)
init_design = GPyOpt.experiment_design.initial_design('random', feasible_region, initial_size)
init_values = n_trials-value_generator(init_design, true_function, n_trials)

# %% [markdown]
# Gaussian inference

# %%
ker_g = GPy.kern.RBF(dims)

# %%
agg = []

for m in [1, 5]:
    
    mult = []
    
    for attempt in range(10):

        X_g = init_design
        Y_g = init_values * m
        trials_g = np.ones(len(X_g)).reshape(-1, 1) * n_trials * m


        m_g = GPy.models.GPRegression(X_g, Y_g / trials_g, ker_g)
        m_g.optimize()

        model_mins_g = []
        model_mins_g.append(np.min(m_g.predict(X_g)[0]))
        
        model_argmins_g = []
        model_argmins_g.append(np.argmin(m_g.predict(X_g)[0]))

        for i in range(n_iteration):
            v_g = lambda x, n_trials: n_trials-value_generator(x, true_function, n_trials=n_trials)
            X_g, Y_g, trials_g, m_g = optimization_step(X_g, Y_g, v_g, space, trials=trials_g,
                                                        n_trials_low=n_trials*m, kernel=ker_g,
                                                        constraints=constraints)
            model_mins_g.append(np.min(m_g.predict(X_g)[0]))
            model_argmins_g.append(np.argmin(m_g.predict(X_g)[0]))
        
        mult.append(np.array([np.array(model_mins_g), X_g, Y_g, trials_g, np.array(model_argmins_g)]))
        
    agg.append(mult)
    
agg = np.array(agg)

# %%
# with open('Results/GP_vs_GGPM/GP_100_500_ship_2.pickle', 'wb') as f:
#     pickle.dump(agg, f)
    
with open('Results/GP_vs_GGPM/GP_100_500_ship_2.pickle', 'rb') as f:
    agg = pickle.load(f)

# %% [markdown]
# Approx inference

# %%
ker_l = GPy.kern.RBF(dims)

# %%
agg_l = []

for m in [1, 5]:
    
    mult = []
    
    for attempt in range(10):

        X_l = init_design
        Y_l = init_values * m
        trials_l = np.ones(len(X_l)).reshape(-1, 1) * n_trials * m

        m_l = GPy.core.GP(X_l, Y_l, kernel=ker_l, 
                          Y_metadata={'trials': trials_l},
                          inference_method=GPy.inference.latent_function_inference.laplace.Laplace(),
                          likelihood=GPy.likelihoods.Binomial())
        m_l.optimize()

        lik = GPy.likelihoods.Bernoulli()
        model_mins_l = []
        model_mins_l.append(lik.gp_link.transf(np.min(m_l._raw_predict(X_l)[0])))
        
        model_argmins_l = []
        model_argmins_l.append(np.argmin(m_l._raw_predict(X_l)[0]))

        for i in range(n_iteration):
            v_l = lambda x, n_trials: n_trials-value_generator(x, true_function, n_trials=n_trials)
            X_l, Y_l, trials_l, m_l = optimization_step(X_l, Y_l, v_l, space, trials=trials_l,
                                                        n_trials_low=n_trials * m, method='laplace',
                                                        kernel=ker_l, constraints=constraints)
            model_mins_l.append(lik.gp_link.transf(np.min(m_l._raw_predict(X_l)[0])))
            model_argmins_l.append(np.argmin(m_l._raw_predict(X_l)[0]))
        
        mult.append(np.array([np.array(model_mins_l), X_l, Y_l, trials_l, np.array(model_argmins_l)]))
        
    agg_l.append(mult)
    
agg_l = np.array(agg_l)

# %%
# with open('Results/GP_vs_GGPM/GGPM_100_500_ship_2.pickle', 'wb') as f:
#     pickle.dump(agg_l, f) 

with open('Results/GP_vs_GGPM/GGPM_100_500_ship_2.pickle', 'rb') as f:
    agg_l = pickle.load(f)

# %%
def return_track(agg, objective, type_track='true'):
    
    tracks = []
    
    if type_track=='true':
        for i in range(len(agg)):
            subtracks = []
            for j in range(len(agg[i])):
                argmins = agg[i, j, 1][agg[i, j, 4]]
                values = objective(argmins)
                subtracks.append(values)
            tracks.append(subtracks)
        return np.array(tracks).mean(axis=1), np.array(tracks).std(axis=1)
            
    
    elif type_track=='noisy':
        
        for i in range(len(agg)):
            subtracks = []
            for j in range(len(agg[i])):
                subtracks.append(np.minimum.accumulate(agg[i, j, 2] / agg[i, j, 3]))
            tracks.append(subtracks)
        return np.array(tracks).mean(axis=1), np.array(tracks).std(axis=1)

# %%
plt.figure(figsize=(10, 5))
plt.plot(agg_l[0, :, 0].mean(), label='100, GGPM')
plt.plot(agg_l[1, :, 0].mean(), label='500, GGPM')

plt.plot(agg[0, :, 0].mean(), label='100, GP')
plt.plot(agg[1, :, 0].mean(), label='500, GP')
plt.title('GP vs GGPM')
plt.xlabel('Iteration')
plt.ylabel('Minimum of the model')
plt.legend()
plt.show()

# %%
# numpy.minimum.accumulate()
plt.figure(figsize=(10, 5))
m = np.array([np.minimum.accumulate(agg_l[0, i, 2] / agg_l[0, i, 3]) for i in range(agg_l.shape[1])]).mean(axis=0)[10:].ravel()
s = np.array([np.minimum.accumulate(agg_l[0, i, 2] / agg_l[0, i, 3]) for i in range(agg_l.shape[1])]).std(axis=0)[10:].ravel()
plt.plot(m, label='Binomial, f=100')
plt.fill_between(np.arange(len(m)), m+s, m-s, alpha=0.1)
# plt.plot(np.array([np.minimum.accumulate(agg_l[0, i, 2] / agg_l[0, i, 3]) for i in range(agg_l.shape[1])]).mean(axis=0)[10:], label='100, Binomial')

m = np.array([np.minimum.accumulate(agg_l[1, i, 2] / agg_l[1, i, 3]) for i in range(agg_l.shape[1])]).mean(axis=0)[10:].ravel()
s = np.array([np.minimum.accumulate(agg_l[1, i, 2] / agg_l[1, i, 3]) for i in range(agg_l.shape[1])]).std(axis=0)[10:].ravel()
plt.plot(m, label='Binomial, f=500')
plt.fill_between(np.arange(len(m)), m+s, m-s, alpha=0.1)
# plt.plot(np.array([np.minimum.accumulate(agg_l[1, i, 2] / agg_l[1, i, 3]) for i in range(agg_l.shape[1])]).mean(axis=0)[10:], label='500, Binomial')

m = np.array([np.minimum.accumulate(agg[0, i, 2] / agg[0, i, 3]) for i in range(agg_l.shape[1])]).mean(axis=0)[10:].ravel()
s = np.array([np.minimum.accumulate(agg[0, i, 2] / agg[0, i, 3]) for i in range(agg_l.shape[1])]).std(axis=0)[10:].ravel()
plt.plot(m, label='Gaussian, f=100')
plt.fill_between(np.arange(len(m)), m+s, m-s, alpha=0.1)
# plt.plot(np.array([np.minimum.accumulate(agg[0, i, 2] / agg[0, i, 3]) for i in range(agg.shape[1])]).mean(axis=0)[10:], label='100, Gaussian')

m = np.array([np.minimum.accumulate(agg[1, i, 2] / agg[1, i, 3]) for i in range(agg_l.shape[1])]).mean(axis=0)[10:].ravel()
s = np.array([np.minimum.accumulate(agg[1, i, 2] / agg[1, i, 3]) for i in range(agg_l.shape[1])]).std(axis=0)[10:].ravel()
plt.plot(m, label='Gaussian, f=500')
plt.fill_between(np.arange(len(m)), m+s, m-s, alpha=0.1)
# plt.plot(np.array([np.minimum.accumulate(agg[1, i, 2] / agg[1, i, 3]) for i in range(agg.shape[1])]).mean(axis=0)[10:], label='500, Gaussian')
# plt.title(r'1-$\pi$')
plt.xlabel('Iteration', fontsize=14)
plt.ylabel('Minimal seen value', fontsize=14)
plt.legend(fontsize=14)
plt.show()

# %%
means, stds = return_track(agg, true_function)
means_l, stds_l = return_track(agg_l, true_function)

plt.figure(figsize=(15, 5))
plt.title('Gaussian vs Binomial, f=100', fontsize=18)
plt.plot(np.arange(len(means[0])),  1-means[0], label='Gaussian, f=100')
plt.fill_between(np.arange(len(means[0])), 1-(means[0]+stds[0]).ravel(), 1-(means[0]-stds[0]).ravel(), alpha=0.1)
plt.plot(np.arange(len(means_l[0])),  1-means_l[0], label='Binomial, f=100')
plt.fill_between(np.arange(len(means_l[0])), 1-(means_l[0]+stds_l[0]).ravel(), 1-(means_l[0]-stds_l[0]).ravel(), alpha=0.1)
plt.ylabel(r'1-$\hat{\pi}(x_{max}(t))$', fontsize=14)
plt.xlabel('Iteration', fontsize=14)
plt.legend()

# %%
means, stds = return_track(agg, true_function)
means_l, stds_l = return_track(agg_l, true_function)

plt.figure(figsize=(15, 5))
plt.title('Gaussian vs Binomial, f=200', fontsize=18)
plt.plot(np.arange(len(means[1])),  1-means[1], label='Gaussian, f=200')
plt.fill_between(np.arange(len(means[1])), 1-(means[1]+stds[1]).ravel(), 1-(means[1]-stds[1]).ravel(), alpha=0.1)
plt.plot(np.arange(len(means_l[1])),  1-means_l[1], label='Binomial, f=200')
plt.fill_between(np.arange(len(means_l[1])), 1-(means_l[1]+stds_l[1]).ravel(), 1-(means_l[1]-stds_l[1]).ravel(), alpha=0.1)
plt.ylabel(r'1-${\pi}(x_{max}(t))$', fontsize=14)
plt.xlabel('Iteration', fontsize=14)
plt.legend()

# %%
noise_dfid = (-means_l[1]+means_l_2[1]) * 0.5
noise_05 = (-means_l[0]+means_l_2[0]) * 0.5

# %%
means_l, stds_l = return_track(agg_l, true_function)
means_l_2, stds_l_2 = return_track(agg_l_2, true_function)

# %%
means_l, stds_l = return_track(agg_l, true_function)
means_l_2, stds_l_2 = return_track(agg_l_2, true_function)

plt.figure(figsize=(15, 5))
plt.title('Single-fidelity vs Multi-fidelity', fontsize=18)
# plt.errorbar(np.arange(len(means_l[0])),  means_l[0], yerr=stds_l[0], label='low')
plt.plot(np.arange(len(means_l[0])),  1-means_l[0], label='Binomial, f=100')
plt.fill_between(np.arange(len(means_l[0])), 1-(means_l[0]+stds_l[0]).ravel(), 1-(means_l[0]-stds_l[0]).ravel(), alpha=0.1)
# plt.errorbar(np.arange(len(means_l[1])),  means_l[1], yerr=stds_l[1], label='high')
plt.plot(np.arange(len(means_l[1])),  1-means_l[1], label='Binomial, f=200')
plt.fill_between(np.arange(len(means_l[1])), 1-(means_l[1]+stds_l[1]).ravel(), 1-(means_l[1]-stds_l[1]).ravel(), alpha=0.1)
# plt.errorbar(np.arange(len(means_l[0])),  means_l[0]+noise_05, yerr=stds_l_2[0], label='0.5')
plt.plot(np.arange(len(means_l[0])),  1-(means_l[0]+noise_05), label='Binomial, decision function 1')
plt.fill_between(np.arange(len(means_l[0])), 1-(means_l[0]+noise_05+stds_l[0]).ravel(), 1-(means_l[0]+noise_05-stds_l[0]).ravel(), alpha=0.1)
# plt.errorbar(np.arange(len(means_l[1])),  means_l[1]+noise_dfid, yerr=stds_l_2[1], label='dfid')
plt.plot(np.arange(len(means_l[1])),  1-(means_l[1]+noise_dfid), label='Binomial, decision function 2')
plt.fill_between(np.arange(len(means_l[1])), 1-(means_l[1]+noise_dfid+stds_l[1]).ravel(), 1-(means_l[1]+noise_dfid-stds_l[1]).ravel(), alpha=0.1)
plt.ylabel(r'$1-\hat{\pi}(x_{max}(t))$', fontsize=14)
plt.xlabel('Iteration', fontsize=14)
plt.legend()

# %% [markdown]
# # Multi fidelity vs single fidelity

# %% [markdown]
# 2d

# %%
ker_f = GPy.kern.RBF(dims)
low_f = 100
high_f = 200

# %%
agg_f = []

for p, d_fid in [(0, False), (0.5, False), (0.5, True)]:

    mult = []

    for attempt in range(10):

        X = init_design
        if p > 0:
            Y = init_values
            trials = np.ones(len(X)).reshape(-1, 1) * low_f
        else:
            Y = init_values * int(high_f / low_f)
            trials = np.ones(len(X)).reshape(-1, 1) * high_f

        lik = GPy.likelihoods.Bernoulli()
        model_mins = []
        model_argmins = []

        for i in range(n_iteration):
            v_f = lambda x, n_trials: n_trials-value_generator(x, true_function, n_trials=n_trials)
            X, Y, trials, m = optimization_step(X, Y, v_f, space, trials=trials,\
                                                n_trials_low=low_f, n_trials_high=high_f,\
                                                method='laplace', kernel=ker_f, treshold_proba=p, \
                                                dinamic_treshold=d_fid, constraints=constraints)
            model_mins.append(float(lik.gp_link.transf(np.min(m._raw_predict(X)[0]))))
            model_argmins.append(int(np.argmin(m._raw_predict(X)[0])))

        mult.append([model_mins, X.astype(float).tolist(), Y.astype(int).tolist(), trials.astype(int).tolist(),\
                     model_argmins])

    agg_f.append(mult)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-aa5e0b472a7b> in <module>()
#      21         for i in range(n_iteration):
#      22             v_f = lambda x, n_trials: n_trials-value_generator(x, true_function, n_trials=n_trials)
# ---> 23             X, Y, trials, m = optimization_step(X, Y, v_f, trials=trials,                                                n_trials_low=low_f, n_trials_high=high_f,                                                method='laplace', kernel=ker_f, treshold_proba=p,                                                 dinamic_treshold=d_fid, constraints=constraints)
#      24             model_mins.append(float(lik.gp_link.transf(np.min(m._raw_predict(X)[0]))))
#      25             model_argmins.append(int(np.argmin(m._raw_predict(X)[0])))
#
# TypeError: optimization_step() missing 1 required positional argument: 'space'

# %%
agg_f_2 = []

for p, d_fid in [(1, False)]:

    mult = []

    for attempt in range(10):

        X = init_design
        if p > 0:
            Y = init_values
            trials = np.ones(len(X)).reshape(-1, 1) * low_f
        else:
            Y = init_values * int(high_f / low_f)
            trials = np.ones(len(X)).reshape(-1, 1) * high_f

        lik = GPy.likelihoods.Bernoulli()
        model_mins = []
        model_argmins = []

        for i in range(n_iteration):
            v_f = lambda x, n_trials: n_trials-value_generator(x, true_function, n_trials=n_trials)
            X, Y, trials, m = optimization_step(X, Y, v_f, space, trials=trials,\
                                                n_trials_low=low_f, n_trials_high=high_f,\
                                                method='laplace', kernel=ker_f, treshold_proba=p, \
                                                dinamic_treshold=d_fid, constraints=constraints)
            model_mins.append(float(lik.gp_link.transf(np.min(m._raw_predict(X)[0]))))
            model_argmins.append(int(np.argmin(m._raw_predict(X)[0])))

        mult.append([model_mins, X.astype(float).tolist(), Y.astype(int).tolist(), trials.astype(int).tolist(),\
                     model_argmins])

    agg_f_2.append(mult)

# %%
agg_f_2 = np.array(agg_f_2)
for i in range(len(agg_f_2)):
    for j in range(len(agg_f_2[i])):
        for k in range(len(agg_f_2[i,j])):
            agg_f_2[i,j,k] = np.array(agg_f_2[i,j,k])

# %%
agg_f = np.array(agg_f)
for i in range(len(agg_f)):
    for j in range(len(agg_f[i])):
        for k in range(len(agg_f[i,j])):
            agg_f[i,j,k] = np.array(agg_f[i,j,k])

# %%
means_f, stds_f = return_track(agg_f, true_function)
means_f_2, stds_f_2 = return_track(agg_f_2, true_function)

plt.figure(figsize=(15, 5))
plt.title('GP vs GGPM n_trials=500')
plt.errorbar(np.arange(len(means_f[0])),  means_f[0], yerr=stds_f[0], label='high')
plt.errorbar(np.arange(len(means_f_2[0])),  means_f_2[0], yerr=stds_f_2[0], label='low')
plt.errorbar(np.arange(len(means_f[1])),  means_f[1], yerr=stds_f[1], label='0.5')
plt.errorbar(np.arange(len(means_f[2])),  means_f[2], yerr=stds_f[2], label='din')
plt.ylabel('Best point true value')
plt.xlabel('iteration')
plt.legend()
print(np.mean(np.mean(agg_f[0, :, 3])))
print(np.mean(np.mean(agg_f_2[0, :, 3])))
print(np.mean(np.mean(agg_f[1, :, 3])))
print(np.mean(np.mean(agg_f[2, :, 3])))
# Out:
# 200.0
# 100.0
# 116.0
# 177.0

# %%
df = pd.DataFrame(['Method', 'Best point'])

# %%
plt.plot(agg_f[0, :, 0].mean(), label='0')
plt.plot(agg_f[1, :, 0].mean(), label='0.5')
plt.plot(agg_f[2, :, 0].mean(), label='1')
plt.legend()

print(agg_f[1, :, 3].mean().mean())
# Out:
# 66.3529411764706

# %%
plt.plot(np.linspace(0, 70, 71)*3, agg_f[0, :, 0].mean(), label='proba=0')
plt.plot(np.linspace(0, 70, 71)*63.74/50, agg_f[1, :, 0].mean(), label='proba=0.5')
plt.plot(agg_f[2, :, 0].mean(), label='proba=1')
plt.legend()
plt.title('Ackley1 2d objective')
plt.xlabel('efforts')
plt.ylabel('objective')

print(agg_f[1, :, 3].mean().mean())
# Out:
# 66.3529411764706

# %%
plt.plot(np.array([np.minimum.accumulate(agg_f[0, i, 2] / agg_f[0, i, 3]) for i in range(agg_f.shape[1])]).mean(axis=0), label='proba=0')
plt.plot(np.array([np.minimum.accumulate(agg_f[1, i, 2] / agg_f[1, i, 3]) for i in range(agg_f.shape[1])]).mean(axis=0), label='proba=0.5')
plt.plot(np.array([np.minimum.accumulate(agg_f[2, i, 2] / agg_f[2, i, 3]) for i in range(agg_f.shape[1])]).mean(axis=0), label='proba=1')
plt.legend()
plt.title('Ackley1 2d objective')
plt.xlabel('n points')
plt.ylabel('Minimal seen value normalized')

print(agg_f[1, :, 3].mean().mean())
# Out:
# 66.3529411764706

# %%
means_f, stds_f = return_track(agg_f, objective)

plt.figure(figsize=(15, 5))
plt.title('Proba 0, 0.5, 1 n_trials=50')
plt.errorbar(np.arange(len(means_f[0])),  means_f[0], yerr=stds_f[0], label='0')
plt.errorbar(np.arange(len(means_f[1])),  means_f[1], yerr=stds_f[1], label='0.5')
plt.errorbar(np.arange(len(means_f[2])),  means_f[2], yerr=stds_f[2], label='1')
plt.ylabel('Best point true value')
plt.xlabel('iteration')
plt.legend()

# %%
print(agg_f[0, :, 3].mean().mean(), agg_f[1, :, 3].mean().mean(), agg_f[2, :, 3].mean().mean())
# Out:
# 132.35294117647058 66.3529411764706 50.0

# %%
with open('Results/single_vs_multi/GGPM_proba_0_0.5_1_ackley1_2d_-1_1.pickle', 'wb') as f:
    pickle.dump(agg_f, f)

# %% [markdown]
# Harder case

# %%
n_trials = 200
n_iteration = 50
initial_size = 10
bound = 1.5
dims = 2

np.random.seed(7)

objective = lambda x: functionDoESpecial(x.reshape(1, -1), f_name)
if f_name in function_dimensions.keys():
    dims = function_dimensions[f_name]

lower_bounds = [-1 * bound] * dims
upper_bounds = [bound] * dims

space = []
for i in range(len(lower_bounds)):
    space.append({'name': 'x'+str(i), 'type': 'continuous', 'domain': (lower_bounds[i], upper_bounds[i])})

feasible_region = GPyOpt.Design_space(space=space)
init_design = GPyOpt.experiment_design.initial_design('random', feasible_region, initial_size)

#search max and min
argmin = differential_evolution(objective, [(-bound, bound)] * dims).x
argmax = differential_evolution(lambda x: -1 * objective(x), [(-bound, bound)] * dims).x
max_v = objective(argmax)
min_v = objective(argmin)
#normalize function
objective = lambda x: (functionDoESpecial(x, f_name) * 0.95 - min_v) / (max_v - min_v)

init_values = value_generator(init_design, objective, n_trials=n_trials).reshape(-1, 1)

# %%
agg_f_h = []

for p in [0, 0.5, 1]:
    
    mult = []
    
    for attempt in range(10):

        X = init_design
        Y = init_values
        trials = np.ones(len(X)).reshape(-1, 1) * n_trials

        m = GPy.core.GP(X, Y, kernel=ker_f, 
                        Y_metadata={'trials': trials},
                        inference_method=GPy.inference.latent_function_inference.laplace.Laplace(),
                        likelihood=GPy.likelihoods.Binomial())
        m.optimize()

        lik = GPy.likelihoods.Bernoulli()
        model_mins = []
        model_mins.append(lik.gp_link.transf(np.min(m._raw_predict(X)[0])))
        
        model_argmins = []
        model_argmins.append(np.argmin(m._raw_predict(X)[0]))

        for i in range(n_iteration):
            v = lambda x, n_trials: value_generator(x, objective, n_trials=n_trials)
            X, Y, trials, m = optimization_step(X, Y, v, lower_bounds=lower_bounds,\
                                                upper_bounds=upper_bounds, trials=trials,\
                                                n_trials_low=n_trials, n_trials_high=5*n_trials,\
                                                method='laplace', kernel=ker_f, treshold_proba=p)
            model_mins.append(lik.gp_link.transf(np.min(m._raw_predict(X)[0])))
            model_argmins.append(np.argmin(m._raw_predict(X)[0]))
        
        mult.append(np.array([np.array(model_mins), X, Y, trials, np.array(model_argmins)]))
        
    agg_f_h.append(mult)
    
agg_f_h = np.array(agg_f_h)

# %%
means_f, stds_f = return_track(agg_f_h, objective)

plt.figure(figsize=(15, 5))
plt.title('Proba 0, 0.5, 1 n_trials=50')
plt.errorbar(np.arange(len(means_f[0])),  means_f[0], yerr=stds_f[0], label='0')
plt.errorbar(np.arange(len(means_f[1])),  means_f[1], yerr=stds_f[1], label='0.5')
plt.errorbar(np.arange(len(means_f[2])),  means_f[2], yerr=stds_f[2], label='1')
plt.ylabel('Best point true value')
plt.xlabel('iteration')
plt.legend()

# %%
agg_f_h[1, :, 3].mean().mean()
# Out:
# 472.0

# %% [markdown]
# one another case

# %%
n_trials = 25
n_iteration = 50
initial_size = 10
# bound = 1.5
dims = 2

np.random.seed(7)

objective = lambda x: functionDoESpecial(x.reshape(1, -1), f_name)
if f_name in function_dimensions.keys():
    dims = function_dimensions[f_name]

lower_bounds = [0] * dims
upper_bounds = [1] * dims

space = []
for i in range(len(lower_bounds)):
    space.append({'name': 'x'+str(i), 'type': 'continuous', 'domain': (lower_bounds[i], upper_bounds[i])})

feasible_region = GPyOpt.Design_space(space=space)
init_design = GPyOpt.experiment_design.initial_design('random', feasible_region, initial_size)

#search max and min
argmin = differential_evolution(objective, [(-bound, bound)] * dims).x
argmax = differential_evolution(lambda x: -1 * objective(x), [(-bound, bound)] * dims).x
max_v = objective(argmax)
min_v = objective(argmin)
#normalize function
objective = lambda x: (functionDoESpecial(x, f_name) * 0.95 - min_v) / (max_v - min_v)

init_values = value_generator(init_design, objective, n_trials=n_trials).reshape(-1, 1)

# %%
agg_f_h = []

for p in [0, 0.5, 1]:
    
    mult = []
    
    for attempt in range(10):

        X = init_design
        Y = init_values
        trials = np.ones(len(X)).reshape(-1, 1) * n_trials

        m = GPy.core.GP(X, Y, kernel=ker_f, 
                        Y_metadata={'trials': trials},
                        inference_method=GPy.inference.latent_function_inference.laplace.Laplace(),
                        likelihood=GPy.likelihoods.Binomial())
        m.optimize()

        lik = GPy.likelihoods.Bernoulli()
        model_mins = []
        model_mins.append(lik.gp_link.transf(np.min(m._raw_predict(X)[0])))
        
        model_argmins = []
        model_argmins.append(np.argmin(m._raw_predict(X)[0]))

        for i in range(n_iteration):
            v = lambda x, n_trials: value_generator(x, objective, n_trials=n_trials)
            X, Y, trials, m = optimization_step(X, Y, v, lower_bounds=lower_bounds,\
                                                upper_bounds=upper_bounds, trials=trials,\
                                                n_trials_low=n_trials, n_trials_high=5*n_trials,\
                                                method='laplace', kernel=ker_f, treshold_proba=p)
            model_mins.append(lik.gp_link.transf(np.min(m._raw_predict(X)[0])))
            model_argmins.append(np.argmin(m._raw_predict(X)[0]))
        
        mult.append(np.array([np.array(model_mins), X, Y, trials, np.array(model_argmins)]))
        
    agg_f_h.append(mult)
    
agg_f_h = np.array(agg_f_h)

# %%
from copy import copy
kek = copy(agg_f_h)

# %%
kek2 = copy(kek)

# %%
[a.tolist() for a in kek2.tolist()]
# Out:
# [[0.9330704515391965,
#   0.9321877835002591,
#   0.942037355960483,
#   0.9377350051419572,
#   0.9412256500690542,
#   0.9425710778929585,
#   0.9397413842694152,
#   0.9404806140650329,
#   0.9408399051262945,
#   0.9414776819074634,
#   0.9404892532697814,
#   0.9413075857649403,
#   0.9415704660084059,
#   0.9418435221362365,
#   0.9422055408366647,
#   0.9429810996700012,
#   0.9409812721478127,
#   0.941204403807675,
#   0.9415624509908592,
#   0.9413340848944666,
#   0.9412711501373012,
#   0.941349788368204,
#   0.9068965253698125,
#   0.912153078618823,
#   0.7982242965499589,
#   0.8009798958323081,
#   0.8034816711303503,
#   0.8031505403574328,
#   0.795841445682394,
#   0.7979535105705329,
#   0.7968107330381897,
#   0.7971172176527395,
#   0.805120375563126,
#   0.8051912643869318,
#   0.8058869510966031,
#   [0.648942894639904, 0.8176332399486212]],
#  [[196],
#   [187],
#   [194],
#   [185],
#   [187],
#   [189],
#   [188],
#   [188],
#   [189],
#   [184],
#   [945],
#   [933],
#   [950],
#   [949],
#   [931],
#   [943],
#   [943],
#   [949],
#   [929],
#   [947],
#   [941],
#   [944],
#   [944],
#   [953],
#   [909],
#   [945],
#   [948],
#   [937],
#   [940],
#   [943],
#   [874],
#   [946],
#   [788],
#   [949],
#   [943],
#   [912],
#   [818],
#   [947],
#   [916],
#   [960],
#   [933],
#   [952],
#   [936],
#   [935],
#   [951],
#   [950],
#   [944],
#   [938],
#   [935],
#   [925],
#   [952],
#   [940],
#   [946],
#   [922],
#   [939],
#   [941],
#   [940],
#   [943],
#   [879],
#   [901]],
#  [[200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0]],
#  [4,
#   10,
#   11,
#   11,
#   11,
#   11,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   8,
#   8,
#   0,
#   0,
#   0,
#   0,
#   30,
#   30,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   58,
#   32],
#  [0.9330703739789706,
#   0.9330704725410115,
#   0.9410769760283123,
#   0.938950219892155,
#   0.938287149373297,
#   0.9382505213485618,
#   0.9398307114358769,
#   0.9386008951157425,
#   0.9387635911470656,
#   0.9382559565739573,
#   0.9360251765270783,
#   0.9383507035520092,
#   0.937932238284145,
#   0.938017990077225,
#   0.9382033999383877,
#   0.939645789367291,
#   0.9408409460914011,
#   0.9416173187699058,
#   0.9412640496578534,
#   0.9411899045514185,
#   0.9416645517356266,
#   0.9417760451062314,
#   0.9415536400791817,
#   0.9416995973955425,
#   0.9399214537771904,
#   0.9396594874902243,
#   0.9401833753364519,
#   0.9407319149547821,
#   0.942058558913291,
#   0.9404117781579345,
#   0.9402886680799942,
#   0.9405921072486145,
#   0.9423879842396756,
#   [-0.10212455523782926, 1.290212008876555],
#   [1.2556333721189938, 0.8740829775650117]],
#  [[196],
#   [187],
#   [194],
#   [185],
#   [187],
#   [189],
#   [188],
#   [188],
#   [189],
#   [184],
#   [947],
#   [937],
#   [937],
#   [938],
#   [949],
#   [935],
#   [944],
#   [937],
#   [930],
#   [949],
#   [936],
#   [942],
#   [944],
#   [951],
#   [947],
#   [955],
#   [939],
#   [931],
#   [949],
#   [946],
#   [940],
#   [939],
#   [929],
#   [932],
#   [943],
#   [952],
#   [955],
#   [956],
#   [937],
#   [954],
#   [954],
#   [956],
#   [926],
#   [952],
#   [947],
#   [930],
#   [936],
#   [953],
#   [942],
#   [940],
#   [932],
#   [940],
#   [935],
#   [924],
#   [948],
#   [939],
#   [951],
#   [944],
#   [956],
#   [939]],
#  [[200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0]],
#  [4,
#   4,
#   4,
#   12,
#   13,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   24,
#   4,
#   24,
#   24,
#   26,
#   24,
#   26,
#   26,
#   26,
#   24,
#   26,
#   26,
#   34,
#   34,
#   34,
#   34,
#   40,
#   40,
#   40,
#   19,
#   19,
#   19,
#   19,
#   19,
#   48,
#   48,
#   48,
#   48,
#   48,
#   48,
#   48,
#   55,
#   55,
#   55,
#   55,
#   55],
#  [0.9351358858159635,
#   0.9330264304620455,
#   0.9318641234355213,
#   0.93651072446951,
#   0.935867479982808,
#   0.9397584399633105,
#   0.9379929521772042,
#   0.9417479989461987,
#   0.9419596700388724,
#   0.942120864223193,
#   0.9431547047417715,
#   0.9419750247429427,
#   0.942053882586925,
#   0.9426929868189553,
#   0.9427313413310411,
#   0.9430034212940834,
#   0.7863265563923012,
#   0.6421537804865213,
#   0.8224249121587521,
#   0.5143315746837039,
#   0.5144671569219358,
#   0.5147165565542079,
#   0.5184814144026484,
#   0.5189252679346082,
#   0.5190188020901157,
#   0.519515113148557,
#   0.5200213175589526,
#   0.520189377339355,
#   0.5210789516046298,
#   0.4905682806233864,
#   0.5062860397869756,
#   [-1.1326353384532546, -1.2070603961851598],
#   [0.4288982638036627, -1.4974287012245528],
#   [-0.6004593432768704, -1.374322849568759]],
#  [[196],
#   [187],
#   [194],
#   [185],
#   [187],
#   [189],
#   [188],
#   [188],
#   [189],
#   [184],
#   [931],
#   [945],
#   [941],
#   [946],
#   [934],
#   [952],
#   [949],
#   [943],
#   [947],
#   [929],
#   [943],
#   [951],
#   [950],
#   [945],
#   [810],
#   [921],
#   [938],
#   [508],
#   [943],
#   [935],
#   [829],
#   [938],
#   [935],
#   [933],
#   [941],
#   [951],
#   [951],
#   [790],
#   [688],
#   [951],
#   [941],
#   [398],
#   [933],
#   [943],
#   [938],
#   [927],
#   [933],
#   [929],
#   [942],
#   [937],
#   [937],
#   [836],
#   [790],
#   [943],
#   [932],
#   [938],
#   [936],
#   [949],
#   [945],
#   [947]],
#  [[200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0]],
#  [4,
#   10,
#   10,
#   10,
#   13,
#   13,
#   15,
#   15,
#   15,
#   18,
#   18,
#   18,
#   18,
#   18,
#   18,
#   18,
#   25,
#   26,
#   24,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   38,
#   39,
#   27,
#   27,
#   41,
#   41,
#   41,
#   41,
#   41,
#   41,
#   41,
#   41,
#   41,
#   41,
#   41,
#   41,
#   41,
#   41,
#   41,
#   41,
#   41,
#   41],
#  [0.9330706436812652,
#   0.9330703994450467,
#   0.9339034540428159,
#   0.9349278570385493,
#   0.9366395431012315,
#   0.9382814207819296,
#   0.9379306348207888,
#   0.9380924479341477,
#   0.939632022151917,
#   0.9391523179810568,
#   0.9407749439934338,
#   0.9408022226575952,
#   0.9422076853940553,
#   0.941049789418253,
#   0.9411131398222408,
#   0.9416686619456937,
#   0.8497821394642273,
#   0.8968170486624426,
#   0.8983595975829303,
#   0.9027011273533041,
#   0.9005230485167937,
#   0.7438843976590431,
#   0.7463734681546698,
#   0.7472812049614004,
#   0.7496790707102878,
#   0.7502076243623448,
#   0.7508680346299732,
#   0.7518482818704639,
#   0.7524743697286507,
#   0.7529631485932231,
#   0.6858245298614014,
#   0.3443525907501789,
#   [1.3373032615505664, 1.116779100682999],
#   [0.6340463550957728, 0.5216449629975511]],
#  [[196],
#   [187],
#   [194],
#   [185],
#   [187],
#   [189],
#   [188],
#   [188],
#   [189],
#   [184],
#   [939],
#   [937],
#   [938],
#   [943],
#   [937],
#   [942],
#   [949],
#   [937],
#   [950],
#   [942],
#   [948],
#   [926],
#   [942],
#   [950],
#   [882],
#   [953],
#   [917],
#   [908],
#   [957],
#   [734],
#   [831],
#   [944],
#   [939],
#   [933],
#   [946],
#   [948],
#   [914],
#   [957],
#   [943],
#   [334],
#   [943],
#   [944],
#   [944],
#   [929],
#   [937],
#   [944],
#   [935],
#   [946],
#   [941],
#   [932],
#   [948],
#   [924],
#   [848],
#   [938],
#   [948],
#   [941],
#   [953],
#   [942],
#   [941],
#   [709]],
#  [[200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0]],
#  [4,
#   4,
#   4,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   20,
#   20,
#   21,
#   21,
#   10,
#   25,
#   24,
#   24,
#   24,
#   29,
#   29,
#   29,
#   29,
#   29,
#   29,
#   29,
#   29,
#   29,
#   29,
#   39,
#   39,
#   39,
#   39,
#   39,
#   39,
#   39,
#   39,
#   39,
#   39,
#   39,
#   39,
#   39,
#   39,
#   39,
#   39,
#   39,
#   39,
#   39,
#   39,
#   39],
#  [0.9330707999054184,
#   0.9327383588478361,
#   0.9462369833061689,
#   0.9411746015595479,
#   0.9415398843735993,
#   0.9379599186510194,
#   0.940099401665745,
#   0.939586820624963,
#   0.8305693724400198,
#   0.849201279430598,
#   0.8046498980608133,
#   0.8510504479503818,
#   0.8526050460706922,
#   0.8629618188815272,
#   0.8672736144457974,
#   0.8694914158879457,
#   0.8577969236247258,
#   0.877468979954648,
#   0.8533576884380609,
#   0.8584094017555448,
#   0.8495826071423938,
#   0.5802390324839389,
#   0.5809018276675324,
#   0.5816417076939886,
#   0.22441203112775376,
#   0.58469173801484,
#   0.5852191703115666,
#   0.5659453123621739,
#   0.5565268294213715,
#   0.5602580363052913,
#   [1.043458858027142, -0.18330204618886223],
#   [0.37461626295114747, -0.8555498558481219],
#   [0.7331579918879068, -1.089068425019174],
#   [-1.1164689194007411, 0.9391503178232842]],
#  [[196],
#   [187],
#   [194],
#   [185],
#   [187],
#   [189],
#   [188],
#   [188],
#   [189],
#   [184],
#   [952],
#   [926],
#   [943],
#   [928],
#   [945],
#   [936],
#   [840],
#   [939],
#   [929],
#   [943],
#   [908],
#   [946],
#   [935],
#   [883],
#   [940],
#   [942],
#   [942],
#   [929],
#   [947],
#   [569],
#   [928],
#   [956],
#   [784],
#   [593],
#   [942],
#   [948],
#   [949],
#   [562],
#   [546],
#   [948],
#   [943],
#   [944],
#   [941],
#   [508],
#   [765],
#   [934],
#   [943],
#   [944],
#   [941],
#   [959],
#   [944],
#   [945],
#   [936],
#   [943],
#   [925],
#   [948],
#   [937],
#   [935],
#   [938],
#   [934]],
#  [[200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0]],
#  [4,
#   10,
#   3,
#   9,
#   9,
#   13,
#   13,
#   13,
#   17,
#   16,
#   19,
#   16,
#   16,
#   16,
#   16,
#   16,
#   25,
#   16,
#   27,
#   16,
#   29,
#   29,
#   29,
#   29,
#   33,
#   29,
#   29,
#   36,
#   37,
#   37,
#   37,
#   37,
#   37,
#   37,
#   43,
#   43,
#   43,
#   43,
#   43,
#   43,
#   43,
#   43,
#   43,
#   43,
#   43,
#   43,
#   43,
#   43,
#   43,
#   43,
#   43],
#  [0.9330709553518824,
#   0.9330704607085859,
#   0.933250972397338,
#   0.9454272421369991,
#   0.9463422077447371,
#   0.9459516678992929,
#   0.9452440312517192,
#   0.9449634599615745,
#   0.9425224098684798,
#   0.9414699136088444,
#   0.9407906796551829,
#   0.9419750221591335,
#   0.9426693720308349,
#   0.9431216415654943,
#   0.9427134621341884,
#   0.9424188288539125,
#   0.9431001733773249,
#   0.943261297471576,
#   0.9429317174350387,
#   0.9428351217795758,
#   0.9434620863248409,
#   0.9438502130772276,
#   0.9439436942902538,
#   0.9436543462299831,
#   0.9434281517392006,
#   0.9432962872319733,
#   [-0.27513810521786375, -0.1383809178576051],
#   [-0.4194117193523592, -0.32381829925501604],
#   [-0.11675389795766433, -0.7275719663516355],
#   [-1.04760451150569, -0.02809160026040236],
#   [-1.4072865413977804, 0.11310117917754314],
#   [0.5347765258742434, -1.241534655527081]],
#  [[196],
#   [187],
#   [194],
#   [185],
#   [187],
#   [189],
#   [188],
#   [188],
#   [189],
#   [184],
#   [941],
#   [954],
#   [950],
#   [944],
#   [941],
#   [943],
#   [923],
#   [932],
#   [934],
#   [955],
#   [951],
#   [949],
#   [937],
#   [938],
#   [954],
#   [946],
#   [937],
#   [941],
#   [956],
#   [952],
#   [946],
#   [937],
#   [938],
#   [940],
#   [950],
#   [947],
#   [947],
#   [941],
#   [942],
#   [924],
#   [941],
#   [945],
#   [949],
#   [948],
#   [948],
#   [940],
#   [942],
#   [923],
#   [953],
#   [929],
#   [937],
#   [941],
#   [943],
#   [954],
#   [942],
#   [937],
#   [950],
#   [954],
#   [949],
#   [952]],
#  [[200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0]],
#  [4,
#   4,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   28,
#   7,
#   30,
#   30,
#   30,
#   30,
#   30,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   26,
#   20,
#   20,
#   30,
#   30,
#   30,
#   20,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30],
#  [0.9433521196562897,
#   0.9330704779876208,
#   0.9364867382317317,
#   0.9402971113229189,
#   0.9395458140360825,
#   0.9408222304736885,
#   0.9409737556332578,
#   0.9424626537291011,
#   0.9425223580582631,
#   0.9427701885739955,
#   0.94260922172151,
#   0.9423917358938602,
#   0.9422208164238242,
#   0.9390665078695098,
#   0.9404715518141887,
#   0.9403377274058423,
#   0.9393296054485004,
#   0.9404589149903139,
#   0.9406373960772662,
#   0.9407295333940995,
#   0.941894432144892,
#   0.9416790433720843,
#   0.942900085879939,
#   [1.437080598867386, 1.0190133683027267],
#   [1.0568139676368062, 0.91751731547033],
#   [0.823846671766392, 1.1566273561011577],
#   [1.3947644440483598, 0.8650130501521244],
#   [1.3409634678781337, -0.12116043088127916],
#   [0.00423701488263175, 1.399775692419722],
#   [1.2899456207362126, 0.46253561715746505]],
#  [[196],
#   [187],
#   [194],
#   [185],
#   [187],
#   [189],
#   [188],
#   [188],
#   [189],
#   [184],
#   [939],
#   [945],
#   [939],
#   [945],
#   [940],
#   [945],
#   [943],
#   [945],
#   [941],
#   [940],
#   [948],
#   [928],
#   [950],
#   [940],
#   [932],
#   [946],
#   [943],
#   [941],
#   [950],
#   [940],
#   [960],
#   [946],
#   [939],
#   [939],
#   [936],
#   [945],
#   [944],
#   [929],
#   [883],
#   [942],
#   [958],
#   [951],
#   [953],
#   [928],
#   [953],
#   [946],
#   [935],
#   [940],
#   [950],
#   [946],
#   [943],
#   [942],
#   [928],
#   [941],
#   [935],
#   [941],
#   [946],
#   [945],
#   [936],
#   [944]],
#  [[200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0]],
#  [4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   25,
#   25,
#   25,
#   25,
#   25,
#   25,
#   25,
#   25,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   46,
#   46,
#   46,
#   46,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50],
#  [0.9330699931434452,
#   0.9330704324901764,
#   0.9389592088082179,
#   0.9437328816683563,
#   0.9459419633215945,
#   0.9456136112304404,
#   0.9444266242635755,
#   0.9478382097831056,
#   0.9473003306335567,
#   0.947783821627903,
#   0.9436870896440045,
#   0.9427756004822818,
#   0.9433758299467724,
#   0.9441562793541904,
#   0.9436468612896889,
#   0.9440148075749543,
#   0.9438607854373712,
#   0.944557554818582,
#   0.944721235006786,
#   0.9445851578453132,
#   0.9450265924169783,
#   [-1.421876170262924, 0.06577051203034096],
#   [-1.0101189879368901, 1.031923481085236],
#   [-1.1334678886953145, -0.8602613267110216],
#   [1.167963062818977, 0.003275469036358558],
#   [-0.3546916590517399, -0.16499741977734209],
#   [-0.4021757552252545, 1.0405260659353157],
#   [1.0503208775827768, 1.14547989116863],
#   [-0.532254082502537, -0.35131666751552193]],
#  [[196],
#   [187],
#   [194],
#   [185],
#   [187],
#   [189],
#   [188],
#   [188],
#   [189],
#   [184],
#   [945],
#   [948],
#   [950],
#   [954],
#   [941],
#   [958],
#   [943],
#   [956],
#   [937],
#   [937],
#   [934],
#   [948],
#   [917],
#   [953],
#   [941],
#   [955],
#   [946],
#   [942],
#   [955],
#   [940],
#   [936],
#   [945],
#   [937],
#   [951],
#   [947],
#   [947],
#   [943],
#   [945],
#   [946],
#   [950],
#   [959],
#   [948],
#   [929],
#   [935],
#   [944],
#   [941],
#   [943],
#   [953],
#   [942],
#   [949],
#   [946],
#   [944],
#   [946],
#   [950],
#   [947],
#   [945],
#   [946],
#   [946],
#   [950],
#   [950]],
#  [[200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0],
#   [1000.0]],
#  [4,
#   4,
#   4,
#   4,
#   3,
#   4,
#   4,
#   3,
#   3,
#   3,
#   9,
#   9,
#   21,
#   21,
#   4,
#   19,
#   19,
#   19,
#   19,
#   19,
#   4,
#   4,
#   4,
#   4,
#   4,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34,
#   34],
#  [0.9433521140299267,
#   0.9330705252142737,
#   0.9398964803353613,
#   0.9374785434119918,
#   0.9370360913943411,
#   0.9400787326175334,
#   0.9438149825173638,
#   0.9435880351861206,
#   0.943300394640003,
#   0.9439563398442885,
#   0.9417488079505794,
#   0.9422312571392,
#   0.943438680512165,
#   0.943121621014892,
#   0.9435135594779912,
#   0.9437657365187607,
#   0.9436832030561516,
#   0.943036701843615,
#   0.9448266836729063,
#   [190],
#   [190],
#   [190],
#   [189],
#   [190],
#   [188],
#   [191],
#   [194],
#   [191],
#   [190],
#   [190],
#   [190],
#   [194],
#   [183],
#   [190],
#   [193],
#   [187],
#   [187],
#   [193],
#   [189],
#   [193],
#   [188],
#   [191],
#   [180],
#   [188],
#   [189],
#   [189],
#   [185],
#   [189],
#   [196],
#   [188],
#   [187],
#   [185],
#   [187],
#   [190],
#   [186],
#   [191],
#   [187],
#   [182],
#   [183],
#   [196],
#   [187],
#   [188]],
#  [[200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0],
#   [200.0]],
#  [4,
#   4,
#   4,
#   4,
#   13,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   19,
#   19,
#   19,
#   19,
#   19,
#   19,
#   19,
#   19,
#   19,
#   19,
#   19,
#   19,
#   19,
#   19,
#   19,
#   19,
#   19,
#   19,
#   19,
#   43,
#   43,
#   45,
#   45,
#   32,
#   32,
#   32,
#   32,
#   32,
#   43,
#   43,
#   43,
#   43,
#   45,
#   32,
#   45,
#   45]]

# %% [markdown]
# # Testing part

# %%
ker_g = GPy.kern.RBF(dims)

# %%
X_g = init_design
Y_g = init_values
trials_g = np.ones(len(X_g)).reshape(-1, 1) * n_trials

m_g = GPy.models.GPRegression(X_g, Y_g / trials_g, ker_g)
m_g.optimize()

model_mins_g = []
model_mins_g.append(np.min(m_g.predict(X_g)[0]))

for i in range(n_iteration):
    v_g = lambda x, n_trials: value_generator(x, objective, n_trials=n_trials)
    X_g, Y_g, trials_g, m_g = optimization_step(X_g, Y_g, v_g, lower_bounds=lower_bounds,\
                                                upper_bounds=upper_bounds, trials=trials_g,\
                                                n_trials_low=n_trials, kernel=ker_g)
    model_mins_g.append(np.min(m_g.predict(X_g)[0]))

# %%
plt.plot(model_mins_g)

# %%
ker_l = GPy.kern.RBF(dims)

# %%
X_l_lf = init_design
Y_l_lf = init_values
trials_l_lf = np.ones(len(X_l_lf)).reshape(-1, 1) * n_trials

m_l_lf = GPy.core.GP(X_l_lf, Y_l_lf, kernel=ker_l, 
                     Y_metadata={'trials': trials_l_lf},
                     inference_method=GPy.inference.latent_function_inference.laplace.Laplace(),
                     likelihood=GPy.likelihoods.Binomial())
m_l_lf.optimize()

lik = GPy.likelihoods.Bernoulli()
model_mins_l_lf = []
model_mins_l_lf.append(lik.gp_link.transf(np.min(m_l_lf._raw_predict(X_l_lf)[0])))

for i in range(n_iteration):
    v_l_lf = lambda x, n_trials: value_generator(x, objective, n_trials=n_trials)
    X_l_lf, Y_l_lf, trials_l_lf, m_l_lf = optimization_step(X_l_lf, Y_l_lf, v_l_lf, lower_bounds=lower_bounds,\
                                                            upper_bounds=upper_bounds, trials=trials_l_lf,\
                                                            n_trials_low=n_trials, method='laplace',\
                                                            kernel=ker_l)
    model_mins_l_lf.append(lik.gp_link.transf(np.min(m_l_lf._raw_predict(X_l_lf)[0])))

# %%
plt.plot(model_mins_l_lf)

# %%
plt.scatter(X_l_lf[:, 0], X_l_lf[:, 1])

# %%
X_l_hf = init_design
Y_l_hf = init_values
trials_l_hf = np.ones(len(X_l_hf)).reshape(-1, 1) * n_trials

m_l_hf = GPy.core.GP(X_l_hf, Y_l_hf, kernel=GPy.kern.RBF(2), 
                     Y_metadata={'trials': trials_l_hf},
                     inference_method=GPy.inference.latent_function_inference.laplace.Laplace(),
                     likelihood=GPy.likelihoods.Binomial())

lik = GPy.likelihoods.Bernoulli()
model_mins_l_hf = []
model_mins_l_hf.append(lik.gp_link.transf(np.min(m_l_hf._raw_predict(X_l_hf)[0])))

for i in range(n_iteration):
    v_l_hf = lambda x, n_trials: value_generator(x, objective, n_trials=n_trials)
    X_l_hf, Y_l_hf, trials_l_hf, m_l_hf = optimization_step(X_l_hf, Y_l_hf, v_l_hf, lower_bounds=lower_bounds,\
                                                            upper_bounds=upper_bounds, trials=trials_l_hf,\
                                                            n_trials_low=n_trials * 25, method='laplace',\
                                                            kernel=GPy.kern.RBF(2))
    model_mins_l_hf.append(lik.gp_link.transf(np.min(m_l_hf._raw_predict(X_l_hf)[0])))

# %%
plt.scatter(X_l_hf[:, 0], X_l_hf[:, 1])

# %%
plt.plot(model_mins_l_lf)
plt.plot(model_mins_l_hf)

# %%
X_l_lf
# Out:
# array([[-1.27107513e+00,  5.37689988e-01],
#        [ 8.39756377e-01,  9.11217108e-01],
#        [-1.84772306e-01, -3.57176601e-01],
#        [ 6.70395533e-01, -1.30219096e+00],
#        [ 1.43396854e+00, -6.35563202e-01],
#        [ 1.15487611e-01,  1.22878058e+00],
#        [ 3.36139098e-03, -8.59843939e-01],
#        [-1.28384660e+00, -1.43628115e-01],
#        [-6.94683060e-01,  1.29361806e+00],
#        [-3.52497523e-04, -1.42530232e+00],
#        [ 9.62167671e-01, -1.46694951e+00],
#        [ 5.61849165e-01, -5.78131840e-01],
#        [ 1.48669113e+00, -1.25237450e+00],
#        [ 6.37849275e-01, -1.22819532e+00],
#        [ 1.21608427e+00, -5.18693492e-01],
#        [ 9.55383716e-01, -5.09189027e-01],
#        [ 1.20987489e+00, -7.85565414e-01],
#        [ 1.14642286e+00, -3.15202808e-01],
#        [ 1.10363130e+00, -9.52135459e-01],
#        [ 1.05330733e+00,  3.16123445e-01],
#        [ 1.14380429e+00,  4.64190820e-01],
#        [ 1.21697314e+00,  2.61449941e-01],
#        [ 1.36153078e+00,  8.21159133e-01],
#        [ 9.39793535e-01, -1.22454902e+00],
#        [ 1.43126006e+00,  7.45087533e-01],
#        [ 1.16809888e+00,  1.17635197e+00],
#        [ 4.07163751e-01, -1.49856715e+00],
#        [ 1.15976976e+00,  4.59650898e-01],
#        [-1.49309553e+00, -1.01095843e+00],
#        [ 1.29006597e+00,  8.32438128e-01],
#        [ 1.30185071e+00,  3.03854919e-01],
#        [ 1.28256640e+00, -3.42013351e-01],
#        [ 1.46932304e+00,  1.44978860e+00],
#        [ 1.26100491e+00,  7.13605469e-02],
#        [ 1.29935873e+00,  5.48433214e-01],
#        [ 1.22430463e+00,  1.27759517e+00],
#        [ 7.55911019e-01,  8.93850117e-01],
#        [ 1.05846469e+00,  6.96232678e-01],
#        [ 4.75247827e-01,  1.38789827e+00],
#        [ 1.20764144e+00,  5.15164838e-01],
#        [ 1.28993400e+00,  1.04737780e+00],
#        [ 1.41649820e+00, -8.22008957e-01],
#        [ 8.93399240e-01,  3.20917742e-01],
#        [ 7.92913967e-01,  9.21893702e-01],
#        [ 1.46226251e+00,  3.98641134e-01],
#        [ 9.47084864e-01,  1.18267707e+00],
#        [ 9.80986680e-01,  1.21457835e+00],
#        [ 1.42317026e+00,  5.31512797e-01],
#        [-3.46031829e-01,  8.75639653e-01],
#        [ 1.04010391e+00,  2.70910821e-01],
#        [ 5.65360249e-01,  1.17125807e+00],
#        [ 1.49790059e+00,  1.35221355e+00],
#        [ 6.12455575e-01,  1.34964676e+00],
#        [ 1.05412701e+00,  1.10436129e+00],
#        [ 1.01133752e+00,  5.04595714e-02],
#        [ 1.25908267e+00,  1.03844532e+00],
#        [-1.33724087e+00,  9.78912061e-01],
#        [ 1.12259447e+00,  3.95017889e-01],
#        [ 8.12414026e-01,  4.42447748e-01],
#        [ 6.47209777e-01,  1.06979792e+00]])

# %%
Y_l_hf/trials_l_hf
# Out:
# array([[0.2  ],
#        [0.185],
#        [0.2  ],
#        [0.18 ],
#        [0.185],
#        [0.19 ],
#        [0.19 ],
#        [0.19 ],
#        [0.19 ],
#        [0.18 ],
#        [0.95 ],
#        [0.93 ],
#        [0.925],
#        [0.935],
#        [0.955],
#        [0.95 ],
#        [0.945],
#        [0.965],
#        [0.935],
#        [0.935],
#        [0.905],
#        [0.94 ],
#        [0.95 ],
#        [0.935],
#        [0.895],
#        [0.94 ],
#        [0.94 ],
#        [0.945],
#        [0.94 ],
#        [0.93 ],
#        [0.96 ],
#        [0.945],
#        [0.915],
#        [0.955],
#        [0.935],
#        [0.94 ],
#        [0.895],
#        [0.955],
#        [0.96 ],
#        [0.925],
#        [0.97 ],
#        [0.95 ],
#        [0.94 ],
#        [0.945],
#        [0.95 ],
#        [0.945],
#        [0.93 ],
#        [0.97 ],
#        [0.955],
#        [0.965],
#        [0.97 ],
#        [0.975],
#        [0.975],
#        [0.96 ],
#        [0.935],
#        [0.94 ],
#        [0.955],
#        [0.955],
#        [0.965],
#        [0.935]])
